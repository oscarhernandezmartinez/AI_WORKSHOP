# %% [markdown]
# # OBJECTIVE
# - The purpose of this script is to analyze and find insights about the EMR Sightings dataset.

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
from datetime import datetime
#from sklearn.model_selection import train_test_split
import sklearn as sl
import matplotlib.pyplot as plt
pd.set_option("display.max_columns",200)
emr_data=pd.read_csv('C:/Users/oscarahe/OneDrive - Intel Corporation/Desktop/Exceles/clustertres.csv')
emr_data
# Out:
#     Unnamed: 0           id  \
# 0           18  14018000516
# 1           32  14018570336
# 2           44  22017895744
# 3           48  22018161164
# 4           81  15015524089
# 5           98  14018655932
# 6          114  14019877013
# 7          121  14017630246
# 8          126  14017859773
# 9          127  14017877858
# 10         132  14017957819
# 11         144  14018510311
# 12         197  14017688800
# 13         198  14017802202
# 14         208  14018388083
# 15         222  14018874892
# 16         238  15015216561
# 17         250  14018545412
# 18         305  14019745300
# 19         317  14018583300
# 20         327  14018847685
# 21         348  14018008333
# 22         349  16019024857
# 23         368  15014729895
#
#                                 sighting_central_root  cluster
# 0   ON QDF Q1CF noticed that fuse pcode_turbo_rati...        3
# 1   Test card issue , need to follow up with that ...        3
# 2   Active idle addition to SST in feature linked ...        3
# 3   Bug on Mcheck with 12way Internleave ->  check...        3
# 4   Declaring apparent GPSB congestion as hardware...        3
# 5            Hynix bug, more details on the hynix com        3
# 6   Known bug https://hsdes.intel.com/appstore/art...        3
# 7   BIOS bug, feature request here https://hsdes.i...        3
# 8   Fuse addressing change for EMR not conveyed to...        3
# 9            Add FUSA_CONST.PATCHLET to patch release        3
# 10  See comments and allied link sighting https://...        3
# 11  aCode patch load timeout extension fixes this ...        3
# 12  This issue was root caused to AXON library tha...        3
# 13                                        Pcode patch        3
# 14  linked server feature on EMR MisCo agenda.  Wo...        3
# 15           Hynix bug, more details on the hynix com        3
# 16  aCode BugECO 13010751184 proximate cause of th...        3
# 17    kernel bug around the variable holding the size        3
# 18                  LeCroy LA message decoding error.        3
# 19           Hynix bug, more details on the hynix com        3
# 20                                       see comments        3
# 21  Alignment of pCode structure allocation to cor...        3
# 22  Astera CXL card currently not supporting MCTP ...        3
# 23  PI5 instance number difference between SPR and...        3

# %% [markdown]
# ##  1. CLEANNING PROCESS/EXPLORATORY ANALYSIS

# %%
emr_data.columns
# Out:
# Index(['id', 'rev', 'updated_date', 'system_updated_date', 'subject', 'tenant',
#        'submitted_date', 'locked_date', 'closed_date', 'eta',
#        ...
#        'sighting_central.sighting.level', 'sighting_central.sighting.vendor',
#        'sighting_central.sighting.port_configs',
#        'sighting_central.sighting.serial_io_interface', 'local_updated_date',
#        'sighting_central.sighting.customer_visible',
#        'sighting_central.sighting.impact', 'collaborators',
#        'sighting_central.sighting.beat_escape_reason_details',
#        'ww_local_updated_date'],
#       dtype='object', length=154)

# %%
emr_data[['sighting_central.sighting.root_cause_description']]
# Out:
#       sighting_central.sighting.root_cause_description
# 0    Problem resolved after re-flashing the MAIN FP...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 367                                                NaN
# 368  PI5 instance number difference between SPR and...
# 369  See extensive remarks from Carlos Ramirez More...
# 370                                                NaN
# 371                                                NaN
#
# [372 rows x 1 columns]

# %%
emr_data.isnull().sum()
# Out:
# id                                                        0
# rev                                                       0
# updated_date                                              0
# system_updated_date                                       0
# subject                                                   0
#                                                        ...
# sighting_central.sighting.customer_visible              371
# sighting_central.sighting.impact                        371
# collaborators                                             0
# sighting_central.sighting.beat_escape_reason_details    360
# ww_local_updated_date                                     0
# Length: 154, dtype: int64

# %%
emr_data1= emr_data[["id","updated_date","component","family","release","priority","title","status_reason","submitted_date","closed_date","owner","sighting.conclusion","sighting.team_found",'sighting_central.sighting.root_cause_description']]
emr_data1
# Out:
#               id      updated_date    component                     family  \
# 0    14018151333  19/12/2022 03:10     hw.power  Emerald Rapids-SP-XNC Die
# 1    14018509356  25/01/2023 00:47          NaN  Emerald Rapids-SP-XNC Die
# 2    14019055430    6/4/2023 20:39       hw.upi  Emerald Rapids-SP-XNC Die
# 3    14019247088  26/05/2023 15:27       hw.upi  Emerald Rapids-SP-XNC Die
# 4    15013435531    12/5/2023 9:47      hw.fuse  Emerald Rapids-SP-XNC Die
# ..           ...               ...          ...                        ...
# 367  15014600103  13/11/2023 22:07      hw.fuse  Emerald Rapids-SP-MCC Die
# 368  15014729895  19/03/2024 09:36    fw.oobmsm  Emerald Rapids-SP-XNC Die
# 369  16022750062  26/12/2023 15:12     fw.pcode  Emerald Rapids-SP-XNC Die
# 370  15014843377    7/1/2024 21:11  hw.big_core  Emerald Rapids-SP-XNC Die
# 371  15015659425  29/04/2024 18:38          NaN  Emerald Rapids-SP-XNC Die
#
#           release  priority  \
# 0    emrsp-xcc-a0    2-high
# 1    emrsp-xcc-a0  3-medium
# 2    emrsp-xcc-a0     4-low
# 3    emrsp-xcc-a0     4-low
# 4    emrsp-xcc-a0    2-high
# ..            ...       ...
# 367  emrsp-mcc-r1  3-medium
# 368  emrsp-xcc-a1    2-high
# 369  emrsp-xcc-a1  3-medium
# 370  emrsp-xcc-a1    2-high
# 371  emrsp-xcc-a1  3-medium
#
#                                                  title  \
# 0    [EMR] EMR system  Throttles due to External pr...
# 1    [EMR-CXL1.1][CXL][2S] BIOS needs to change Mod...
# 2    [XPV AVE] [EMR XCC A0] [UPI GEN5 SIV] Rx JTOL ...
# 3    [XPV AVE] [EMR XCC A0] [UPI GEN5 SIV] Rx JTOL ...
# 4    [EMR XCC ES2]Request sighting report for track...
# ..                                                 ...
# 367  [Lenovo-TDC\Seoul] Wrong PIROM contents on off...
# 368  [Bytedance][Yichun][Nettrix] NVMe PCIe speed d...
# 369  [EMR A1][2S][PMSS][SST]: CLOS 0 and CLOS 1 sub...
# 370  [TriRiver V2][EMR]CPU has thermal hot when run...
# 371  [EMR] [Mixed Rank] Enhanced warning of type 31...
#
#                  status_reason    submitted_date       closed_date     owner  \
# 0        rejected.not_a_defect    6/12/2022 9:04  19/12/2022 03:09   adabney
# 1    rejected.filed_by_mistake  24/01/2023 17:26  25/01/2023 00:47  aebenavi
# 2        rejected.not_a_defect  29/03/2023 23:37    6/4/2023 20:38  ahinojos
# 3        rejected.not_a_defect  27/04/2023 16:40  26/05/2023 15:27  ahinojos
# 4              rejected.merged    12/5/2023 9:09    12/5/2023 9:47      achu
# ..                         ...               ...               ...       ...
# 367     complete.wont_validate    1/11/2023 3:42  13/11/2023 22:07   wuweber
# 368   root_caused.awaiting_fix  22/11/2023 02:58               NaN  wenweita
# 369      rejected.not_a_defect   6/12/2023 20:49  26/12/2023 15:05  thangama
# 370      rejected.not_a_defect    7/12/2023 8:53    7/1/2024 21:11    wtian4
# 371  rejected.cannot_reproduce  18/03/2024 06:07  27/04/2024 03:09  tharihar
#
#         sighting.conclusion sighting.team_found  \
# 0                    hw.bug                 ptp
# 1    no_root_cause.rejected                arch
# 2                 not_a_bug                  ev
# 3                 not_a_bug                  ev
# 4    no_root_cause.rejected    customer_support
# ..                      ...                 ...
# 367                bios.bug    customer_support
# 368                  fw.bug    customer_support
# 369               not_a_bug         bu_platform
# 370               not_a_bug    customer_support
# 371  no_root_cause.rejected         bu_platform
#
#       sighting_central.sighting.root_cause_description
# 0    Problem resolved after re-flashing the MAIN FP...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 367                                                NaN
# 368  PI5 instance number difference between SPR and...
# 369  See extensive remarks from Carlos Ramirez More...
# 370                                                NaN
# 371                                                NaN
#
# [372 rows x 14 columns]

# %%
emr_data1.dtypes
# Out:
# id                                                   int64
# updated_date                                        object
# component                                           object
# family                                              object
# release                                             object
# priority                                            object
# title                                               object
# status_reason                                       object
# submitted_date                                      object
# closed_date                                         object
# owner                                               object
# sighting.conclusion                                 object
# sighting.team_found                                 object
# sighting_central.sighting.root_cause_description    object
# dtype: object

# %%
emr_data1.isnull().sum()
# Out:
# id                                                    0
# updated_date                                          0
# component                                            28
# family                                                0
# release                                               0
# priority                                              0
# title                                                 0
# status_reason                                         0
# submitted_date                                        0
# closed_date                                          19
# owner                                                 0
# sighting.conclusion                                   2
# sighting.team_found                                   0
# sighting_central.sighting.root_cause_description    204
# dtype: int64

# %%
emr_data['subject'].value_counts()
# Out:
# subject
# sighting    372
# Name: count, dtype: int64

# %%
emr_data['sighting_central.sighting.root_cause_description'].value_counts()
# Out:
# sighting_central.sighting.root_cause_description
# Resolved by EMR LTM patch 0x3 (second version)                                                                                                                                                      3
# Hynix bug, more details on the hynix com                                                                                                                                                            3
# Apparently lost the SMM considerations in the EDS some time after SKX                                                                                                                               3
# unexpected Power Virus Protector parameter change                                                                                                                                                   2
# Bug was resolved when multiple approaches to reducing IOSF-SB loading were combined in a single patch.  Not much of an RCA.                                                                         2
#                                                                                                                                                                                                    ..
# Will start RPP process for this - not a design bug - but may be a manufacturing test hole - or an infant failure.                                                                                   1
# BIOS bug, feature request here https://hsdes.intel.com/appstore/article/#/22015797612                                                                                                               1
# Fuse addressing change for EMR not conveyed to pCode workaround                                                                                                                                     1
# Add FUSA_CONST.PATCHLET to patch release                                                                                                                                                            1
# See extensive remarks from Carlos Ramirez Moreno (comment https://hsdes.intel.com/appstore/article/#/14611715550 below) regarding expected behavior in view of the Hardware P-state MSR setting.    1
# Name: count, Length: 155, dtype: int64

# %%
emr_data['status_reason'].value_counts()
# Out:
# status_reason
# rejected.not_a_defect        117
# complete.validated           117
# rejected.merged               34
# rejected.wont_do              27
# complete.wont_validate        20
# complete                      17
# rejected.filed_by_mistake     14
# root_caused.pursuing_fix      10
# rejected.cannot_reproduce      7
# root_caused.awaiting_fix       7
# open.clone                     2
# Name: count, dtype: int64

# %%
emr_data1['owner'].value_counts().head(50)
# Out:
# owner
# nljimene    13
# ombecerr    11
# csong20      9
# coramire     9
# bachavez     7
# juanman1     7
# jalonsoj     6
# cadoming     6
# bcalhoon     6
# hmpicosm     5
# sbarrios     5
# srotich      5
# prmarque     5
# jgodoyde     5
# jochoa       5
# jsfernan     4
# chinnai      4
# gfuentes     4
# jjabudtr     4
# arnavarr     4
# jaimeihe     4
# jkalina      4
# gomeseva     3
# juanasol     3
# lmalagon     3
# joseitz      3
# ipaezcas     3
# eballest     3
# jrdelsor     3
# dfloress     3
# ogalvezr     3
# hkenya       3
# cprivera     3
# thangama     3
# ovazquez     3
# spullell     3
# spashya      3
# umeraban     2
# jmachina     2
# iherrer      2
# taylorjo     2
# jjbautis     2
# gsotoram     2
# vchalla      2
# tolasupo     2
# skaliraj     2
# jorgecor     2
# leiren       2
# ivangele     2
# kumarc       2
# Name: count, dtype: int64

# %%
#### CLEANING FUNCTION

def tweak_hw(emr_data1):
    return (emr_data1
            
            .assign(status_reason=lambda df_: df_.status_reason.str.replace(".", "_"))
            .assign(release=lambda df_: df_.release.str.replace("-", "_"))
            .assign(priority=lambda df_: df_.priority.replace(
                {"1-showstopper": "showstopper", "2-high": "high", "3-medium": "medium", "4-low": "low"}
            )) 
            .assign(priority_num=lambda df_: df_.priority.map({
                "showstopper": 1, "high": 2, "medium": 3, "low": 4
            }))
            .assign(closed_date=lambda df_: pd.to_datetime(df_.closed_date, errors='coerce',dayfirst=True))
            .assign(closed_date=lambda df_: df_.closed_date.fillna(pd.Timestamp(datetime.today())))
            .assign(submitted_date=lambda df_: pd.to_datetime(df_.submitted_date, errors='coerce',dayfirst=True))
            .assign(submitted_year=lambda df_: df_.submitted_date.dt.year)
            .assign(days_between=lambda df_: (df_.closed_date - df_.submitted_date).dt.days)
            .assign(component=lambda df_: df_.component.fillna("NA"))
            .assign(submitted_year=lambda df_: df_.submitted_year.astype('int64'))
            .assign(days_between=lambda df_: df_.days_between.astype('int64'))
            .assign(sighting_central_root=lambda df_: df_['sighting_central.sighting.root_cause_description'].fillna("Not Root Cause")).drop(columns=['sighting_central.sighting.root_cause_description'])
            )

# %%
emr_data1=tweak_hw(emr_data1)
emr_data1
# Out:
#               id      updated_date    component                     family  \
# 0    14018151333  19/12/2022 03:10     hw.power  Emerald Rapids-SP-XNC Die
# 1    14018509356  25/01/2023 00:47           NA  Emerald Rapids-SP-XNC Die
# 2    14019055430    6/4/2023 20:39       hw.upi  Emerald Rapids-SP-XNC Die
# 3    14019247088  26/05/2023 15:27       hw.upi  Emerald Rapids-SP-XNC Die
# 4    15013435531    12/5/2023 9:47      hw.fuse  Emerald Rapids-SP-XNC Die
# ..           ...               ...          ...                        ...
# 367  15014600103  13/11/2023 22:07      hw.fuse  Emerald Rapids-SP-MCC Die
# 368  15014729895  19/03/2024 09:36    fw.oobmsm  Emerald Rapids-SP-XNC Die
# 369  16022750062  26/12/2023 15:12     fw.pcode  Emerald Rapids-SP-XNC Die
# 370  15014843377    7/1/2024 21:11  hw.big_core  Emerald Rapids-SP-XNC Die
# 371  15015659425  29/04/2024 18:38           NA  Emerald Rapids-SP-XNC Die
#
#           release priority                                              title  \
# 0    emrsp_xcc_a0     high  [EMR] EMR system  Throttles due to External pr...
# 1    emrsp_xcc_a0   medium  [EMR-CXL1.1][CXL][2S] BIOS needs to change Mod...
# 2    emrsp_xcc_a0      low  [XPV AVE] [EMR XCC A0] [UPI GEN5 SIV] Rx JTOL ...
# 3    emrsp_xcc_a0      low  [XPV AVE] [EMR XCC A0] [UPI GEN5 SIV] Rx JTOL ...
# 4    emrsp_xcc_a0     high  [EMR XCC ES2]Request sighting report for track...
# ..            ...      ...                                                ...
# 367  emrsp_mcc_r1   medium  [Lenovo-TDC\Seoul] Wrong PIROM contents on off...
# 368  emrsp_xcc_a1     high  [Bytedance][Yichun][Nettrix] NVMe PCIe speed d...
# 369  emrsp_xcc_a1   medium  [EMR A1][2S][PMSS][SST]: CLOS 0 and CLOS 1 sub...
# 370  emrsp_xcc_a1     high  [TriRiver V2][EMR]CPU has thermal hot when run...
# 371  emrsp_xcc_a1   medium  [EMR] [Mixed Rank] Enhanced warning of type 31...
#
#                  status_reason      submitted_date                closed_date  \
# 0        rejected_not_a_defect 2022-12-06 09:04:00 2022-12-19 03:09:00.000000
# 1    rejected_filed_by_mistake 2023-01-24 17:26:00 2023-01-25 00:47:00.000000
# 2        rejected_not_a_defect 2023-03-29 23:37:00 2023-04-06 20:38:00.000000
# 3        rejected_not_a_defect 2023-04-27 16:40:00 2023-05-26 15:27:00.000000
# 4              rejected_merged 2023-05-12 09:09:00 2023-05-12 09:47:00.000000
# ..                         ...                 ...                        ...
# 367     complete_wont_validate 2023-11-01 03:42:00 2023-11-13 22:07:00.000000
# 368   root_caused_awaiting_fix 2023-11-22 02:58:00 2024-12-02 17:36:33.276956
# 369      rejected_not_a_defect 2023-12-06 20:49:00 2023-12-26 15:05:00.000000
# 370      rejected_not_a_defect 2023-12-07 08:53:00 2024-01-07 21:11:00.000000
# 371  rejected_cannot_reproduce 2024-03-18 06:07:00 2024-04-27 03:09:00.000000
#
#         owner     sighting.conclusion sighting.team_found  priority_num  \
# 0     adabney                  hw.bug                 ptp             2
# 1    aebenavi  no_root_cause.rejected                arch             3
# 2    ahinojos               not_a_bug                  ev             4
# 3    ahinojos               not_a_bug                  ev             4
# 4        achu  no_root_cause.rejected    customer_support             2
# ..        ...                     ...                 ...           ...
# 367   wuweber                bios.bug    customer_support             3
# 368  wenweita                  fw.bug    customer_support             2
# 369  thangama               not_a_bug         bu_platform             3
# 370    wtian4               not_a_bug    customer_support             2
# 371  tharihar  no_root_cause.rejected         bu_platform             3
#
#      submitted_year  days_between  \
# 0              2022            12
# 1              2023             0
# 2              2023             7
# 3              2023            28
# 4              2023             0
# ..              ...           ...
# 367            2023            12
# 368            2023           376
# 369            2023            19
# 370            2023            31
# 371            2024            39
#
#                                  sighting_central_root
# 0    Problem resolved after re-flashing the MAIN FP...
# 1                                       Not Root Cause
# 2                                       Not Root Cause
# 3                                       Not Root Cause
# 4                                       Not Root Cause
# ..                                                 ...
# 367                                     Not Root Cause
# 368  PI5 instance number difference between SPR and...
# 369  See extensive remarks from Carlos Ramirez More...
# 370                                     Not Root Cause
# 371                                     Not Root Cause
#
# [372 rows x 17 columns]

# %%
#emr_data1= emr_data1.fillna("NA")

# %%
emr_data1.dtypes
# Out:
# id                                int64
# updated_date                     object
# component                        object
# family                           object
# release                          object
# priority                         object
# title                            object
# status_reason                    object
# submitted_date           datetime64[ns]
# closed_date              datetime64[ns]
# owner                            object
# sighting.conclusion              object
# sighting.team_found              object
# priority_num                      int64
# submitted_year                    int64
# days_between                      int64
# sighting_central_root            object
# dtype: object

# %%
emr_data1.isnull().sum()
# Out:
# id                       0
# updated_date             0
# component                0
# family                   0
# release                  0
# priority                 0
# title                    0
# status_reason            0
# submitted_date           0
# closed_date              0
# owner                    0
# sighting.conclusion      2
# sighting.team_found      0
# priority_num             0
# submitted_year           0
# days_between             0
# sighting_central_root    0
# dtype: int64

# %%
emr_data1.sort_values("submitted_year")
# Out:
#               id      updated_date              component  \
# 0    14018151333  19/12/2022 03:10               hw.power
# 126  14017859773  10/10/2023 21:51                 hw.dmi
# 125  14017840950  13/05/2023 21:02               bios.mrc
# 124  14017766920  24/11/2022 15:06  val.env.configuration
# 123  14017766856  24/11/2022 15:04  val.env.configuration
# ..           ...               ...                    ...
# 82   16023465464  13/05/2024 15:23               fw.acode
# 81   15015524089  24/06/2024 18:40               fw.acode
# 80   22019353310    5/3/2024 17:54                hw.perf
# 345  15015657452  24/07/2024 21:55                     NA
# 371  15015659425  29/04/2024 18:38                     NA
#
#                         family       release     priority  \
# 0    Emerald Rapids-SP-XNC Die  emrsp_xcc_a0         high
# 126  Emerald Rapids-SP-XNC Die  emrsp_xcc_a0       medium
# 125  Emerald Rapids-SP-XNC Die  emrsp_xcc_a0       medium
# 124  Emerald Rapids-SP-XNC Die  emrsp_xcc_a0  showstopper
# 123  Emerald Rapids-SP-XNC Die  emrsp_xcc_a0  showstopper
# ..                         ...           ...          ...
# 82   Emerald Rapids-SP-XNC Die  emrsp_xcc_a1         high
# 81   Emerald Rapids-SP-XNC Die  emrsp_xcc_a1  showstopper
# 80   Emerald Rapids-SP-XNC Die  emrsp_xcc_a1       medium
# 345  Emerald Rapids-SP-XNC Die  emrsp_xcc_a1       medium
# 371  Emerald Rapids-SP-XNC Die  emrsp_xcc_a1       medium
#
#                                                  title  \
# 0    [EMR] EMR system  Throttles due to External pr...
# 126  [EMR XCC A0 PO][PC6] DMI not reporting idle an...
# 125  [EMR A0 PO][EMR DDR EV] Lane dropping/ low mar...
# 124  EMR PPO UPS dynamic string for FIVR DDR cause ...
# 123  EMR PPO UPS dynamic string for SCFIO enables i...
# ..                                                 ...
# 82   [Cluster][FLEX EMR_XCC A1][Multiple] DISPATCHE...
# 81   [ByteDance][EMR][Yichun][Nettrix] Report CPU0 ...
# 80   EMR with Cassandra workload and Zstd compressi...
# 345  [EMR A0 ][XCC][2S][RAS] [Archer City] Unexpect...
# 371  [EMR] [Mixed Rank] Enhanced warning of type 31...
#
#                  status_reason      submitted_date                closed_date  \
# 0        rejected_not_a_defect 2022-12-06 09:04:00 2022-12-19 03:09:00.000000
# 126         complete_validated 2022-10-29 00:41:00 2023-10-10 21:50:00.000000
# 125         complete_validated 2022-10-27 04:23:00 2023-01-05 17:39:00.000000
# 124         complete_validated 2022-10-17 22:48:00 2022-11-24 15:06:00.000000
# 123         complete_validated 2022-10-17 22:42:00 2022-11-24 15:04:00.000000
# ..                         ...                 ...                        ...
# 82    root_caused_awaiting_fix 2024-03-04 11:41:00 2024-10-10 11:07:12.477414
# 81    root_caused_awaiting_fix 2024-02-27 01:29:00 2024-10-10 11:07:12.477414
# 80   rejected_cannot_reproduce 2024-01-17 17:44:00 2024-03-05 17:54:00.000000
# 345      rejected_not_a_defect 2024-03-18 04:25:00 2024-07-24 21:55:00.000000
# 371  rejected_cannot_reproduce 2024-03-18 06:07:00 2024-04-27 03:09:00.000000
#
#         owner     sighting.conclusion sighting.team_found  priority_num  \
# 0     adabney                  hw.bug                 ptp             2
# 126  hmpicosm                  hw.bug         sv.enabling             3
# 125    hkenya                  hw.bug                  ev             3
# 124   jkalina                 env.bug         sv.enabling             1
# 123   jkalina                 env.bug         sv.enabling             1
# ..        ...                     ...                 ...           ...
# 82     appaji                  fw.bug         bu_platform             2
# 81      cma16                  hw.bug    customer_support             1
# 80   bravindr  no_root_cause.rejected         bu_platform             3
# 345      staj               not_a_bug         bu_platform             3
# 371  tharihar  no_root_cause.rejected         bu_platform             3
#
#      submitted_year  days_between
# 0              2022            12
# 126            2022           346
# 125            2022            70
# 124            2022            37
# 123            2022            37
# ..              ...           ...
# 82             2024           219
# 81             2024           226
# 80             2024            48
# 345            2024           128
# 371            2024            39
#
# [372 rows x 16 columns]

# %%
emr_data1['submitted_year'].value_counts()
emr_data1
# Out:
#               id      updated_date    component                     family  \
# 0    14018151333  19/12/2022 03:10     hw.power  Emerald Rapids-SP-XNC Die
# 1    14018509356  25/01/2023 00:47           NA  Emerald Rapids-SP-XNC Die
# 2    14019055430    6/4/2023 20:39       hw.upi  Emerald Rapids-SP-XNC Die
# 3    14019247088  26/05/2023 15:27       hw.upi  Emerald Rapids-SP-XNC Die
# 4    15013435531    12/5/2023 9:47      hw.fuse  Emerald Rapids-SP-XNC Die
# ..           ...               ...          ...                        ...
# 367  15014600103  13/11/2023 22:07      hw.fuse  Emerald Rapids-SP-MCC Die
# 368  15014729895  19/03/2024 09:36    fw.oobmsm  Emerald Rapids-SP-XNC Die
# 369  16022750062  26/12/2023 15:12     fw.pcode  Emerald Rapids-SP-XNC Die
# 370  15014843377    7/1/2024 21:11  hw.big_core  Emerald Rapids-SP-XNC Die
# 371  15015659425  29/04/2024 18:38           NA  Emerald Rapids-SP-XNC Die
#
#           release priority                                              title  \
# 0    emrsp_xcc_a0     high  [EMR] EMR system  Throttles due to External pr...
# 1    emrsp_xcc_a0   medium  [EMR-CXL1.1][CXL][2S] BIOS needs to change Mod...
# 2    emrsp_xcc_a0      low  [XPV AVE] [EMR XCC A0] [UPI GEN5 SIV] Rx JTOL ...
# 3    emrsp_xcc_a0      low  [XPV AVE] [EMR XCC A0] [UPI GEN5 SIV] Rx JTOL ...
# 4    emrsp_xcc_a0     high  [EMR XCC ES2]Request sighting report for track...
# ..            ...      ...                                                ...
# 367  emrsp_mcc_r1   medium  [Lenovo-TDC\Seoul] Wrong PIROM contents on off...
# 368  emrsp_xcc_a1     high  [Bytedance][Yichun][Nettrix] NVMe PCIe speed d...
# 369  emrsp_xcc_a1   medium  [EMR A1][2S][PMSS][SST]: CLOS 0 and CLOS 1 sub...
# 370  emrsp_xcc_a1     high  [TriRiver V2][EMR]CPU has thermal hot when run...
# 371  emrsp_xcc_a1   medium  [EMR] [Mixed Rank] Enhanced warning of type 31...
#
#                  status_reason      submitted_date                closed_date  \
# 0        rejected_not_a_defect 2022-12-06 09:04:00 2022-12-19 03:09:00.000000
# 1    rejected_filed_by_mistake 2023-01-24 17:26:00 2023-01-25 00:47:00.000000
# 2        rejected_not_a_defect 2023-03-29 23:37:00 2023-04-06 20:38:00.000000
# 3        rejected_not_a_defect 2023-04-27 16:40:00 2023-05-26 15:27:00.000000
# 4              rejected_merged 2023-05-12 09:09:00 2023-05-12 09:47:00.000000
# ..                         ...                 ...                        ...
# 367     complete_wont_validate 2023-11-01 03:42:00 2023-11-13 22:07:00.000000
# 368   root_caused_awaiting_fix 2023-11-22 02:58:00 2024-10-10 11:07:12.477414
# 369      rejected_not_a_defect 2023-12-06 20:49:00 2023-12-26 15:05:00.000000
# 370      rejected_not_a_defect 2023-12-07 08:53:00 2024-01-07 21:11:00.000000
# 371  rejected_cannot_reproduce 2024-03-18 06:07:00 2024-04-27 03:09:00.000000
#
#         owner     sighting.conclusion sighting.team_found  priority_num  \
# 0     adabney                  hw.bug                 ptp             2
# 1    aebenavi  no_root_cause.rejected                arch             3
# 2    ahinojos               not_a_bug                  ev             4
# 3    ahinojos               not_a_bug                  ev             4
# 4        achu  no_root_cause.rejected    customer_support             2
# ..        ...                     ...                 ...           ...
# 367   wuweber                bios.bug    customer_support             3
# 368  wenweita                  fw.bug    customer_support             2
# 369  thangama               not_a_bug         bu_platform             3
# 370    wtian4               not_a_bug    customer_support             2
# 371  tharihar  no_root_cause.rejected         bu_platform             3
#
#      submitted_year  days_between
# 0              2022            12
# 1              2023             0
# 2              2023             7
# 3              2023            28
# 4              2023             0
# ..              ...           ...
# 367            2023            12
# 368            2023           323
# 369            2023            19
# 370            2023            31
# 371            2024            39
#
# [372 rows x 16 columns]

# %%
#### HOW MANY MAX DAYS BY PRIORITY, ID, and STATUS REASON

#emr_data1[["priority","id","status_reason","days_between"]].groupby("priority").min()
emr_data1.sort_values("days_between",ascending=True).head(10)
# Out:
#               id      updated_date component                     family  \
# 334  14019049670  29/03/2023 15:44    fw.ltm  Emerald Rapids-SP-XNC Die
# 339  22017914017  13/04/2023 21:34        NA  Emerald Rapids-SP-XNC Die
# 223  16020022626  14/03/2023 14:55  fw.other  Emerald Rapids-SP-XNC Die
# 173  15013780841  20/07/2023 13:29        NA  Emerald Rapids-SP-MCC Die
# 315  14018467522  25/01/2023 01:05    hw.pma  Emerald Rapids-SP-XNC Die
# 66   15013778573   10/7/2023 14:16        NA  Emerald Rapids-SP-XNC Die
# 182  14020329138   12/9/2023 22:17        NA  Emerald Rapids-SP-XNC Die
# 166  16020779913  23/05/2023 18:57    hw.upi  Emerald Rapids-SP-XNC Die
# 152  14018662693    11/2/2023 4:06  hw.punit  Emerald Rapids-SP-XNC Die
# 73   22018704545   10/8/2023 19:36   hw.fuse  Emerald Rapids-SP-MCC Die
#
#           release     priority  \
# 334  emrsp_xcc_a0       medium
# 339  emrsp_xcc_a0         high
# 223  emrsp_xcc_a0         high
# 173  emrsp_mcc_r1         high
# 315  emrsp_xcc_a0  showstopper
# 66   emrsp_xcc_a0       medium
# 182  emrsp_xcc_a1       medium
# 166  emrsp_xcc_a0         high
# 152  emrsp_xcc_a0       medium
# 73   emrsp_mcc_r1       medium
#
#                                                  title  \
# 334  [EMR XCC][A0][RAS]: rdIAmsr using PECI returns...
# 339  [EMR]: Performance drop by 5% when acode_dram ...
# 223  [EMR A0 VV][HSIO][2S][PCIe] MCE hit after rese...
# 173  EMR DSA DPDK dmadev_autotest failed with "Data...
# 315  [EMR-XCC][A0 VIS][Incoming DPM][PM] Units with...
# 66   [Cluster][EMR][XCC][A0][BKC13]MLC latency perf...
# 182                  [EMR][TME] Booting halts when TME
# 166  [EMR A0 VV][HSIO][2S][UPI][XCC]: Observing CPU...
# 152  [EMR] OOBMSM timeout (700ms) requires BMC to r...
# 73   [EMR][MCC][R1][SST-TF] virtual.pcode_runtime_f...
#
#                  status_reason      submitted_date         closed_date  \
# 334  rejected_filed_by_mistake 2023-03-29 15:32:00 2023-03-29 09:42:00
# 339  rejected_filed_by_mistake 2023-04-13 17:00:00 2023-04-13 16:34:00
# 223      rejected_not_a_defect 2023-03-13 12:14:00 2023-03-13 22:26:00
# 173      rejected_not_a_defect 2023-07-11 02:52:00 2023-07-11 22:39:00
# 315  rejected_filed_by_mistake 2023-01-19 18:15:00 2023-01-19 19:45:00
# 66   rejected_filed_by_mistake 2023-07-10 08:27:00 2023-07-10 14:13:00
# 182      rejected_not_a_defect 2023-09-12 18:28:00 2023-09-12 22:17:00
# 166      rejected_not_a_defect 2023-05-23 06:07:00 2023-05-23 18:57:00
# 152           rejected_wont_do 2023-02-11 03:58:00 2023-02-11 04:01:00
# 73   rejected_filed_by_mistake 2023-08-10 18:38:00 2023-08-10 19:36:00
#
#         owner     sighting.conclusion sighting.team_found  priority_num  \
# 334  sbarrios  no_root_cause.rejected                  sv             3
# 339   srotich  no_root_cause.rejected                 ptp             2
# 223    kumarc               not_a_bug         bu_platform             2
# 173  gustavom               not_a_bug    customer_support             2
# 315  scerdasr  no_root_cause.rejected             mfg.ppv             1
# 66   bushengw  no_root_cause.rejected         bu_platform             3
# 182  jmorales               not_a_bug                  sv             3
# 166  johnsonl               not_a_bug         bu_platform             2
# 152  jcgindle  no_root_cause.rejected    customer_support             3
# 73   coramire  no_root_cause.rejected                  sv             3
#
#      submitted_year  days_between
# 334            2023            -1
# 339            2023            -1
# 223            2023             0
# 173            2023             0
# 315            2023             0
# 66             2023             0
# 182            2023             0
# 166            2023             0
# 152            2023             0
# 73             2023             0

# %%
emr_data1.sort_values("days_between",ascending=False).head(10)
# Out:
#               id      updated_date              component  \
# 171  14019660995  13/02/2024 14:39                 hw.cxl
# 306  14019800162    4/3/2024 22:09                 hw.cxl
# 183  14020397220    6/3/2024 16:50            hw.big_core
# 310  14020733102    6/3/2024 16:51               fw.acode
# 86   14017745683  10/10/2023 20:10  val.env.configuration
# 77   14020784944  21/05/2024 23:37            hw.big_core
# 198  14017802202  10/10/2023 20:05               fw.pcode
# 88   14017804101  10/10/2023 23:00               fw.ucode
# 126  14017859773  10/10/2023 21:51                 hw.dmi
# 368  15014729895  19/03/2024 09:36              fw.oobmsm
#
#                         family       release priority  \
# 171  Emerald Rapids-SP-MCC Die  emrsp_mcc_r0   medium
# 306  Emerald Rapids-SP-XNC Die  emrsp_xcc_a1   medium
# 183  Emerald Rapids-SP-XNC Die  emrsp_xcc_a1   medium
# 310  Emerald Rapids-SP-XNC Die  emrsp_xcc_a1   medium
# 86   Emerald Rapids-SP-XNC Die  emrsp_xcc_a0     high
# 77   Emerald Rapids-SP-XNC Die  emrsp_xcc_a1   medium
# 198  Emerald Rapids-SP-XNC Die  emrsp_xcc_a0   medium
# 88   Emerald Rapids-SP-XNC Die  emrsp_xcc_a0      low
# 126  Emerald Rapids-SP-XNC Die  emrsp_xcc_a0   medium
# 368  Emerald Rapids-SP-XNC Die  emrsp_xcc_a1     high
#
#                                                  title  \
# 171  [EMR][CXL][MCC]Post moka shows MCA_IAL_TX_RUN_...
# 306  [EMR][A1][CXL] reserved bits are set in H2D da...
# 183  [Cluster][MCC-XCC R1-A1]  MCA_DISPATCHER_RUN_B...
# 310  [Cluster][XCC A1][MCA_WATCHDOG_TIMEOUT_BULK_CR...
# 86   [EMR XCC] Prod POF enablement: S3M is not resp...
# 77   [EMR][XCC][A1] EMR PPV - DRG Sanity MUC Failin...
# 198  [EMR-PO][A0][RAS]: CHA mc_status & UBOX mc_mis...
# 88   EMR PO:  Errata update - MSR for DDIO Mask won...
# 126  [EMR XCC A0 PO][PC6] DMI not reporting idle an...
# 368  [Bytedance][Yichun][Nettrix] NVMe PCIe speed d...
#
#                 status_reason      submitted_date                closed_date  \
# 171  root_caused_awaiting_fix 2023-06-16 18:06:00 2024-10-31 10:22:41.334856
# 306  root_caused_pursuing_fix 2023-07-06 23:46:00 2024-10-31 10:22:41.334856
# 183  root_caused_awaiting_fix 2023-09-20 20:13:00 2024-10-31 10:22:41.334856
# 310  root_caused_pursuing_fix 2023-10-31 02:42:00 2024-10-31 10:22:41.334856
# 86         complete_validated 2022-10-13 21:50:00 2023-10-10 20:10:00.000000
# 77   root_caused_pursuing_fix 2023-11-06 16:50:00 2024-10-31 10:22:41.334856
# 198        complete_validated 2022-10-21 14:53:00 2023-10-10 20:04:00.000000
# 88     complete_wont_validate 2022-10-21 17:54:00 2023-10-10 23:00:00.000000
# 126        complete_validated 2022-10-29 00:41:00 2023-10-10 21:50:00.000000
# 368  root_caused_awaiting_fix 2023-11-22 02:58:00 2024-10-31 10:22:41.334856
#
#         owner sighting.conclusion sighting.team_found  priority_num  \
# 171  jclopezg              hw.bug                  sv             3
# 306  prmarque             env.bug                  sv             3
# 183    jochoa              fw.bug          sv.cluster             3
# 310   rmiller             hw.arch          sv.cluster             3
# 86   dramosol             env.bug         sv.enabling             2
# 77   bcalhoon           hw.tuning             mfg.ppv             3
# 198  jrdelsor              fw.bug         sv.enabling             3
# 88   dvalgano              hw.bug        sv.execution             4
# 126  hmpicosm              hw.bug         sv.enabling             3
# 368  wenweita              fw.bug    customer_support             2
#
#      submitted_year  days_between
# 171            2023           502
# 306            2023           482
# 183            2023           406
# 310            2023           366
# 86             2022           361
# 77             2023           359
# 198            2022           354
# 88             2022           354
# 126            2022           346
# 368            2023           344

# %%
emr_data1['closed_date'] = emr_data1['closed_date'].astype(str)
notclosed=emr_data1[emr_data1['closed_date'].str.contains('2024-10-31')]

notclosed
# Out:
#               id      updated_date       component                     family  \
# 77   14020784944  21/05/2024 23:37     hw.big_core  Emerald Rapids-SP-XNC Die
# 78   15014859759    3/2/2024 14:45        fw.other  Emerald Rapids-SP-XNC Die
# 81   15015524089  24/06/2024 18:40        fw.acode  Emerald Rapids-SP-XNC Die
# 82   16023465464  13/05/2024 15:23        fw.acode  Emerald Rapids-SP-XNC Die
# 120  14021867778  15/07/2024 17:51        fw.pcode  Emerald Rapids-SP-XNC Die
# 171  14019660995  13/02/2024 14:39          hw.cxl  Emerald Rapids-SP-MCC Die
# 183  14020397220    6/3/2024 16:50     hw.big_core  Emerald Rapids-SP-XNC Die
# 187  15014854421     1/7/2024 6:22       hw.memory  Emerald Rapids-SP-XNC Die
# 188  14021433475  29/07/2024 17:43       hw.memory  Emerald Rapids-SP-XNC Die
# 189  14021450544  15/07/2024 17:51       hw.uncore  Emerald Rapids-SP-XNC Die
# 196  15016140390  16/08/2024 05:53  fw.ucode.patch  Emerald Rapids-SP-XNC Die
# 237  14021187328    7/3/2024 17:11        fw.ucode  Emerald Rapids-SP-XNC Die
# 238  15015216561    3/5/2024 14:26        fw.acode  Emerald Rapids-SP-XNC Die
# 240  22019713637  18/07/2024 23:56        fw.acode  Emerald Rapids-SP-XNC Die
# 241  15015930498  17/06/2024 16:25        hw.pcie5  Emerald Rapids-SP-XNC Die
# 306  14019800162    4/3/2024 22:09          hw.cxl  Emerald Rapids-SP-XNC Die
# 310  14020733102    6/3/2024 16:51        fw.acode  Emerald Rapids-SP-XNC Die
# 312  15016383479  19/08/2024 15:26          hw.cha  Emerald Rapids-SP-XNC Die
# 368  15014729895  19/03/2024 09:36       fw.oobmsm  Emerald Rapids-SP-XNC Die
#
#           release     priority  \
# 77   emrsp_xcc_a1       medium
# 78   emrsp_xcc_a1       medium
# 81   emrsp_xcc_a1  showstopper
# 82   emrsp_xcc_a1         high
# 120  emrsp_xcc_a1         high
# 171  emrsp_mcc_r0       medium
# 183  emrsp_xcc_a1       medium
# 187  emrsp_xcc_a1       medium
# 188  emrsp_xcc_a0       medium
# 189  emrsp_xcc_a1       medium
# 196  emrsp_xcc_a1       medium
# 237  emrsp_xcc_a1       medium
# 238  emrsp_xcc_a1         high
# 240  emrsp_xcc_a1       medium
# 241  emrsp_xcc_a1         high
# 306  emrsp_xcc_a1       medium
# 310  emrsp_xcc_a1       medium
# 312  emrsp_xcc_a1         high
# 368  emrsp_xcc_a1         high
#
#                                                  title  \
# 77   [EMR][XCC][A1] EMR PPV - DRG Sanity MUC Failin...
# 78   [Cluster][EMR][XCC][A1][BKC24] SPECCPU povray ...
# 81   [ByteDance][EMR][Yichun][Nettrix] Report CPU0 ...
# 82   [Cluster][FLEX EMR_XCC A1][Multiple] DISPATCHE...
# 120  Acode PMA registers are missing from crashlog ...
# 171  [EMR][CXL][MCC]Post moka shows MCA_IAL_TX_RUN_...
# 183  [Cluster][MCC-XCC R1-A1]  MCA_DISPATCHER_RUN_B...
# 187  [EGS EMR][Archer City][A1][2S][RAS] Patrol scr...
# 188  [EMR XCC MMX][mmx_32gb][A1] MemMatrix MRharass...
# 189  [Cluster] [EMR A1] MCE PCU: Pkgc_Allow_L1_Erro...
# 196  [ByteDance][EMR][Perf] iperf performance with ...
# 237  [EMR A1][Cafe OSPL] Acode/Ucode GPSB TO to OOB...
# 238  [ByteDance][EMR[Perf] ffmpeg low performance i...
# 240  [EMR XCC A1]SAF scan can sometimes report scan...
# 241  [TriRiver v2][EMR]128k Seq Write doesn't meet ...
# 306  [EMR][A1][CXL] reserved bits are set in H2D da...
# 310  [Cluster][XCC A1][MCA_WATCHDOG_TIMEOUT_BULK_CR...
# 312  [HPE-TDC/DL380 Gen11] UMCE bank 0x4 occurs whe...
# 368  [Bytedance][Yichun][Nettrix] NVMe PCIe speed d...
#
#                 status_reason      submitted_date                 closed_date  \
# 77   root_caused_pursuing_fix 2023-11-06 16:50:00  2024-10-31 10:22:41.334856
# 78   root_caused_awaiting_fix 2023-12-11 01:22:00  2024-10-31 10:22:41.334856
# 81   root_caused_awaiting_fix 2024-02-27 01:29:00  2024-10-31 10:22:41.334856
# 82   root_caused_awaiting_fix 2024-03-04 11:41:00  2024-10-31 10:22:41.334856
# 120  root_caused_pursuing_fix 2024-03-06 21:46:00  2024-10-31 10:22:41.334856
# 171  root_caused_awaiting_fix 2023-06-16 18:06:00  2024-10-31 10:22:41.334856
# 183  root_caused_awaiting_fix 2023-09-20 20:13:00  2024-10-31 10:22:41.334856
# 187                open_clone 2023-12-08 17:58:00  2024-10-31 10:22:41.334856
# 188  root_caused_pursuing_fix 2024-01-22 19:05:00  2024-10-31 10:22:41.334856
# 189  root_caused_pursuing_fix 2024-01-24 01:40:00  2024-10-31 10:22:41.334856
# 196  root_caused_pursuing_fix 2024-05-28 00:47:00  2024-10-31 10:22:41.334856
# 237  root_caused_pursuing_fix 2023-12-14 22:22:00  2024-10-31 10:22:41.334856
# 238  root_caused_awaiting_fix 2024-01-24 09:20:00  2024-10-31 10:22:41.334856
# 240  root_caused_pursuing_fix 2024-03-26 18:41:00  2024-10-31 10:22:41.334856
# 241  root_caused_pursuing_fix 2024-04-23 10:56:00  2024-10-31 10:22:41.334856
# 306  root_caused_pursuing_fix 2023-07-06 23:46:00  2024-10-31 10:22:41.334856
# 310  root_caused_pursuing_fix 2023-10-31 02:42:00  2024-10-31 10:22:41.334856
# 312                open_clone 2024-07-02 15:59:00  2024-10-31 10:22:41.334856
# 368  root_caused_awaiting_fix 2023-11-22 02:58:00  2024-10-31 10:22:41.334856
#
#         owner sighting.conclusion sighting.team_found  priority_num  \
# 77   bcalhoon           hw.tuning             mfg.ppv             3
# 78   bushengw              fw.bug         bu_platform             3
# 81      cma16              hw.bug    customer_support             1
# 82     appaji              fw.bug         bu_platform             2
# 120   gilbert             fw.arch             fw.eval             2
# 171  jclopezg              hw.bug                  sv             3
# 183    jochoa              fw.bug          sv.cluster             3
# 187     jli61                 NaN         bu_platform             3
# 188  jgodoyde              fw.bug                  sv             3
# 189    jochoa             hw.arch          sv.cluster             3
# 196  guanguan              hw.bug    customer_support             3
# 237  jtgilmer              fw.bug             sv.core             3
# 238    leiren              fw.bug    customer_support             2
# 240    lbphan              fw.bug         bu_platform             3
# 241    leiren              hw.bug    customer_support             2
# 306  prmarque             env.bug                  sv             3
# 310   rmiller             hw.arch          sv.cluster             3
# 312  peijungl                 NaN    customer_support             2
# 368  wenweita              fw.bug    customer_support             2
#
#      submitted_year  days_between
# 77             2023           359
# 78             2023           325
# 81             2024           247
# 82             2024           240
# 120            2024           238
# 171            2023           502
# 183            2023           406
# 187            2023           327
# 188            2024           282
# 189            2024           281
# 196            2024           156
# 237            2023           321
# 238            2024           281
# 240            2024           218
# 241            2024           190
# 306            2023           482
# 310            2023           366
# 312            2024           120
# 368            2023           344

# %%
emr_data1[["component"]].value_counts()
#db=emr_data1["component"]=="NA"
#emr_data1.loc[db]
# Out:
# component
# hw.memory                62
# NA                       28
# bios.mrc                 25
# hw.fuse                  24
# hw.perf                  21
# fw.acode                 21
# fw.pcode                 17
# hw.pcie5                 15
# hw.cha                   12
# fw.ucode                 12
# val.env.tool             11
# val.env.configuration    10
# hw.cxl                   10
# hw.big_core               9
# bios                      9
# hw.upi                    8
# fw.ltm                    7
# fw.other                  6
# hw.mesh                   5
# val.env.test              5
# hw.ras                    4
# fw.ucode.patch            4
# hw.m2iosf                 4
# hw.reset                  3
# hw.punit                  3
# fw.mcheck                 3
# sw.application            2
# hw.configrom              2
# val.env.debug_tools       2
# fw.cpm                    2
# hw.pma                    2
# hw.power                  2
# hw.virtualization         1
# val.env.content           1
# hw.uncore                 1
# val.env.execution         1
# hw.ubox                   1
# hw.s3m                    1
# sw                        1
# fw.oobmsm                 1
# hw.perf.rdt               1
# bios.changerequest        1
# board.platform            1
# hw.memory.dimm            1
# hw.iommu                  1
# fw.hsphy.pcie             1
# hw.fivr                   1
# hw.dmi                    1
# hw.csme                   1
# hw.clocks                 1
# fw.hsphy.upi              1
# fw.ucode.big_core         1
# fw.s3m                    1
# hw.gpio                   1
# Name: count, dtype: int64

# %%
#### CLOSE_DATE2 IS DATETIME
#### SUBMITTED_DATE2 IS DATETIME
#### YEAR_SUBMITTED IS INT64
#### DAYS_BETWEEN IS INT64
#### PRIORITY_NUM IS INT64

emr_data1.dtypes
# Out:
# id                              int64
# updated_date                   object
# component                      object
# family                         object
# release                        object
# priority                       object
# title                          object
# status_reason                  object
# submitted_date         datetime64[ns]
# closed_date            datetime64[ns]
# owner                          object
# sighting.conclusion            object
# sighting.team_found            object
# priority_num                    int64
# submitted_year                  int64
# days_between                    int64
# dtype: object

# %%
emr_data1.isnull().sum()
# Out:
# id                      0
# updated_date            0
# component              28
# family                  0
# release                 0
# priority                0
# title                   0
# status_reason           0
# submitted_date          0
# closed_date            19
# owner                   0
# sighting.conclusion     2
# sighting.team_found     0
# priority_num            0
# submitted_year          0
# days_between           19
# dtype: int64

# %%
emr_data1['days_between'].mean()
# Out:
# 85.8252688172043

# %%
#### WE CAN CONFIRM THAT THE MAXIMUN DAYS BETWEEN SUBMITTED DATE AND CLOSED DATE ARE 361.
#### WE CAN CONFIRM THAT THE MINIMUN DAYS BETWEEN SUBMITTED DATE AND CLOSED DATE ARE -1.

emr_data1.describe()
# Out:
#                  id                 submitted_date  priority_num  \
# count  3.720000e+02                            372    372.000000
# mean   1.498100e+10  2023-04-21 22:56:32.419354880      2.674731
# min    1.401763e+10            2022-09-21 16:18:00      1.000000
# 25%    1.401855e+10            2023-01-23 05:54:00      2.000000
# 50%    1.401928e+10            2023-03-24 17:01:00      3.000000
# 75%    1.402184e+10            2023-06-22 23:36:45      3.000000
# max    2.202018e+10            2024-07-04 06:17:00      4.000000
# std    2.313178e+09                            NaN      0.744508
#
#        submitted_year  days_between
# count      372.000000    372.000000
# mean      2022.862903     85.825269
# min       2022.000000     -1.000000
# 25%       2023.000000     13.000000
# 50%       2023.000000     35.500000
# 75%       2023.000000    120.500000
# max       2024.000000    502.000000
# std          0.492554    105.406895

# %%
#### "rejected_filed_by_mistake" ROWS

#sr=emr_new["status_reason2"]=="rejected_filed_by_mistake"
#emr_new.loc[sr]


emr_data1["status_reason"].value_counts()[emr_data1['status_reason'].value_counts()==emr_data1['status_reason'].value_counts()]
# Out:
# status_reason
# rejected_not_a_defect        117
# complete_validated           117
# rejected_merged               34
# rejected_wont_do              27
# complete_wont_validate        20
# complete                      17
# rejected_filed_by_mistake     14
# root_caused_pursuing_fix      10
# rejected_cannot_reproduce      7
# root_caused_awaiting_fix       7
# open_clone                     2
# Name: count, dtype: int64

# %%
percentages = emr_data1['priority'].value_counts(normalize=True) * 100

print(percentages)
# Out:
# priority
# medium         47.043011
# high           36.290323
# low            12.365591
# showstopper     4.301075
# Name: proportion, dtype: float64

# %%
percentages = emr_data1['status_reason'].value_counts(normalize=True) * 100

print(percentages)
# Out:
# status_reason
# rejected_not_a_defect        31.451613
# complete_validated           31.451613
# rejected_merged               9.139785
# rejected_wont_do              7.258065
# complete_wont_validate        5.376344
# complete                      4.569892
# rejected_filed_by_mistake     3.763441
# root_caused_pursuing_fix      2.688172
# rejected_cannot_reproduce     1.881720
# root_caused_awaiting_fix      1.881720
# open_clone                    0.537634
# Name: proportion, dtype: float64

# %%
#### "-1" ROWS

db=emr_data1["days_between"]==-1
emr_data1.loc[db]
# Out:
#               id      updated_date component                     family  \
# 334  14019049670  29/03/2023 15:44    fw.ltm  Emerald Rapids-SP-XNC Die
# 339  22017914017  13/04/2023 21:34        NA  Emerald Rapids-SP-XNC Die
#
#           release priority                                              title  \
# 334  emrsp_xcc_a0   medium  [EMR XCC][A0][RAS]: rdIAmsr using PECI returns...
# 339  emrsp_xcc_a0     high  [EMR]: Performance drop by 5% when acode_dram ...
#
#                  status_reason      submitted_date  \
# 334  rejected_filed_by_mistake 2023-03-29 15:32:00
# 339  rejected_filed_by_mistake 2023-04-13 17:00:00
#
#                     closed_date     owner     sighting.conclusion  \
# 334  2023-03-29 09:42:00.000000  sbarrios  no_root_cause.rejected
# 339  2023-04-13 16:34:00.000000   srotich  no_root_cause.rejected
#
#     sighting.team_found  priority_num  submitted_year  days_between
# 334                  sv             3            2023            -1
# 339                 ptp             2            2023            -1

# %%
import matplotlib.pyplot as plt

import seaborn as sns


plt.figure(figsize=(10, 6))
sns.barplot(x='priority', y='days_between', data=emr_data1)
plt.xlabel('Priority')
plt.ylabel('Days Between')
plt.title('Box Plot of Days Between by Priority')
plt.show()

# %%
#import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.barplot(data=emr_data1, x='priority', y='days_between', hue='submitted_year', dodge=False)
plt.title('Days Between by Priority Level')
plt.ylabel('Days Between')
plt.xlabel('Priority')
plt.xticks(rotation=45)
plt.show()

# %%
# Calculate Q1 (25th percentile) and Q3 (75th percentile) for 'days_between'
Q1 = emr_data1['days_between'].quantile(0.25)
Q3 = emr_data1['days_between'].quantile(0.75)
IQR = Q3 - Q1

# Define outlier thresholds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter to get outliers (values below the lower bound or above the upper bound)
outliers = emr_data1[(emr_data1['days_between'] < lower_bound) | (emr_data1['days_between'] > upper_bound)]


outliers_table = outliers[['title','priority','days_between','submitted_year']]
outliers_table.sort_values(by='days_between', ascending=False)
# Out:
#                                                  title priority  days_between  \
# 171  [EMR][CXL][MCC]Post moka shows MCA_IAL_TX_RUN_...   medium           514
# 306  [EMR][A1][CXL] reserved bits are set in H2D da...   medium           494
# 183  [Cluster][MCC-XCC R1-A1]  MCA_DISPATCHER_RUN_B...   medium           418
# 310  [Cluster][XCC A1][MCA_WATCHDOG_TIMEOUT_BULK_CR...   medium           378
# 77   [EMR][XCC][A1] EMR PPV - DRG Sanity MUC Failin...   medium           371
# 86   [EMR XCC] Prod POF enablement: S3M is not resp...     high           361
# 368  [Bytedance][Yichun][Nettrix] NVMe PCIe speed d...     high           356
# 198  [EMR-PO][A0][RAS]: CHA mc_status & UBOX mc_mis...   medium           354
# 88   EMR PO:  Errata update - MSR for DDIO Mask won...      low           354
# 126  [EMR XCC A0 PO][PC6] DMI not reporting idle an...   medium           346
# 187  [EGS EMR][Archer City][A1][2S][RAS] Patrol scr...   medium           339
# 78   [Cluster][EMR][XCC][A1][BKC24] SPECCPU povray ...   medium           337
# 130  [EMRPO A0][RAS] m2mem_fuse_addr_based_mem_mirr...   medium           336
# 129          Lock hang on missing UPI AD credit return     high           336
# 289  [EMR PO] BMC not adjusting fan speed with CPU ...   medium           333
# 237  [EMR A1][Cafe OSPL] Acode/Ucode GPSB TO to OOB...   medium           333
# 202  [EMR] No ptrr support for Samsung 16Gb 1B proc...   medium           330
# 203  [EGS EMR][Archer City] IP prefetcher stride mu...     high           328
# 18   [EMR XCC] Wrong Turbo Bin bucket 7 impacting P...   medium           327
# 313  [PO][EGS_Refresh][EMR][2S][DDR5+CXL]: Machine ...   medium           327
# 348  dfx_counter_core_cc6_enter offset should be 12...      low           327
# 91   [EMR][PTV]  System early Cattrip On 385W EMR P...   medium           327
# 17   [EMR XCC] Wrong mapping on SST-TF mailbox for ...     high           326
# 291  [EMR][Rice]security issue with link_mca_ctl.ma...   medium           314
# 349  [PO][EGS_Refresh][EMR][2S][DDR5+CXL]: Uncorrec...     high           314
# 76   [EMR][EMR_A1_SVOS_VV][PECI] pecirand return 0x...   medium           312
# 136  [EMR][A0][PO][GNR][RAS] Array bist taking too ...   medium           307
# 244  [NPK - ITH] Unable to send S3M FW traces from ...   medium           306
# 23   [EMR MCC] Wrong mapping on SST-TF mailbox for ...     high           305
# 188  [EMR XCC MMX][mmx_32gb][A1] MemMatrix MRharass...   medium           294
# 238  [ByteDance][EMR[Perf] ffmpeg low performance i...     high           293
# 137  [EMR A0][PM] aCode Periodic CC6 auto-demotion ...     high           293
# 189  [Cluster] [EMR A1] MCE PCU: Pkgc_Allow_L1_Erro...   medium           293
#
#      submitted_year
# 171            2023
# 306            2023
# 183            2023
# 310            2023
# 77             2023
# 86             2022
# 368            2023
# 198            2022
# 88             2022
# 126            2022
# 187            2023
# 78             2023
# 130            2022
# 129            2022
# 289            2022
# 237            2023
# 202            2022
# 203            2022
# 18             2022
# 313            2022
# 348            2022
# 91             2022
# 17             2022
# 291            2022
# 349            2022
# 76             2023
# 136            2022
# 244            2022
# 23             2022
# 188            2024
# 238            2024
# 137            2022
# 189            2024

# %%
print(IQR) ### it's used to identify the spread of the central portion of the data,captures the middle 50%.
print(lower_bound) 
print(upper_bound) ### Any data points with values above this threshold are considered outliers.
# Out:
# 109.0
# -150.5
# 285.5

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=emr_data1, x='priority', y='days_between')
plt.title('Distribution of Days Between by Priority Level')
plt.ylabel('Days Between')
plt.xlabel('Priority')
plt.xticks(rotation=45)
plt.show()

# %%
fd=emr_data1[emr_data1['days_between'] >= 281.75]
fd
# Out:
#               id      updated_date              component  \
# 17   14018000504   9/10/2023 23:39                hw.fuse
# 18   14018000516  10/10/2023 21:53                hw.fuse
# 23   14018183474  10/10/2023 20:11                hw.fuse
# 76   14020089463  19/06/2024 04:14                 fw.ltm
# 77   14020784944  21/05/2024 23:37            hw.big_core
# 78   15014859759    3/2/2024 14:45               fw.other
# 86   14017745683  10/10/2023 20:10  val.env.configuration
# 88   14017804101  10/10/2023 23:00               fw.ucode
# 91   14018006530  10/10/2023 21:54  val.env.configuration
# 126  14017859773  10/10/2023 21:51                 hw.dmi
# 129  14017921210   9/10/2023 23:39                 hw.cha
# 130  14017929270  10/10/2023 21:51                hw.fuse
# 136  14018157349     4/1/2024 8:49               fw.ucode
# 137  22016373172  10/10/2023 21:49         fw.ucode.patch
# 171  14019660995  13/02/2024 14:39                 hw.cxl
# 183  14020397220    6/3/2024 16:50            hw.big_core
# 187  15014854421     1/7/2024 6:22              hw.memory
# 188  14021433475  29/07/2024 17:43              hw.memory
# 198  14017802202  10/10/2023 20:05               fw.pcode
# 202  14017977160  10/10/2023 21:53              hw.memory
# 203  22016178791  10/10/2023 20:13               fw.ucode
# 237  14021187328    7/3/2024 17:11               fw.ucode
# 244  14018174304  10/10/2023 21:55                 hw.s3m
# 289  14017960380  10/10/2023 21:52               fw.other
# 291  14018113855  10/10/2023 21:54              hw.memory
# 306  14019800162    4/3/2024 22:09                 hw.cxl
# 310  14020733102    6/3/2024 16:51               fw.acode
# 313  16018856603  10/10/2023 22:56                 hw.cha
# 348  14018008333  10/10/2023 23:00               fw.pcode
# 349  16019024857  10/10/2023 20:12                 hw.cha
# 368  15014729895  19/03/2024 09:36              fw.oobmsm
#
#                         family       release priority  \
# 17   Emerald Rapids-SP-XNC Die  emrsp_xcc_a0     high
# 18   Emerald Rapids-SP-XNC Die  emrsp_xcc_a0   medium
# 23   Emerald Rapids-SP-MCC Die  emrsp_mcc_r0     high
# 76   Emerald Rapids-SP-XNC Die  emrsp_xcc_a1   medium
# 77   Emerald Rapids-SP-XNC Die  emrsp_xcc_a1   medium
# 78   Emerald Rapids-SP-XNC Die  emrsp_xcc_a1   medium
# 86   Emerald Rapids-SP-XNC Die  emrsp_xcc_a0     high
# 88   Emerald Rapids-SP-XNC Die  emrsp_xcc_a0      low
# 91   Emerald Rapids-SP-XNC Die  emrsp_xcc_a0   medium
# 126  Emerald Rapids-SP-XNC Die  emrsp_xcc_a0   medium
# 129  Emerald Rapids-SP-XNC Die  emrsp_xcc_a0     high
# 130  Emerald Rapids-SP-XNC Die  emrsp_xcc_a0   medium
# 136  Emerald Rapids-SP-XNC Die  emrsp_xcc_a0   medium
# 137  Emerald Rapids-SP-XNC Die  emrsp_xcc_a0     high
# 171  Emerald Rapids-SP-MCC Die  emrsp_mcc_r0   medium
# 183  Emerald Rapids-SP-XNC Die  emrsp_xcc_a1   medium
# 187  Emerald Rapids-SP-XNC Die  emrsp_xcc_a1   medium
# 188  Emerald Rapids-SP-XNC Die  emrsp_xcc_a0   medium
# 198  Emerald Rapids-SP-XNC Die  emrsp_xcc_a0   medium
# 202  Emerald Rapids-SP-XNC Die  emrsp_xcc_a0   medium
# 203  Emerald Rapids-SP-XNC Die  emrsp_xcc_a0     high
# 237  Emerald Rapids-SP-XNC Die  emrsp_xcc_a1   medium
# 244  Emerald Rapids-SP-XNC Die  emrsp_xcc_a0   medium
# 289  Emerald Rapids-SP-XNC Die  emrsp_xcc_a0   medium
# 291  Emerald Rapids-SP-XNC Die  emrsp_xcc_a0   medium
# 306  Emerald Rapids-SP-XNC Die  emrsp_xcc_a1   medium
# 310  Emerald Rapids-SP-XNC Die  emrsp_xcc_a1   medium
# 313  Emerald Rapids-SP-XNC Die  emrsp_xcc_a0   medium
# 348  Emerald Rapids-SP-XNC Die  emrsp_xcc_a0      low
# 349  Emerald Rapids-SP-XNC Die  emrsp_xcc_a0     high
# 368  Emerald Rapids-SP-XNC Die  emrsp_xcc_a1     high
#
#                                                  title  \
# 17   [EMR XCC] Wrong mapping on SST-TF mailbox for ...
# 18   [EMR XCC] Wrong Turbo Bin bucket 7 impacting P...
# 23   [EMR MCC] Wrong mapping on SST-TF mailbox for ...
# 76   [EMR][EMR_A1_SVOS_VV][PECI] pecirand return 0x...
# 77   [EMR][XCC][A1] EMR PPV - DRG Sanity MUC Failin...
# 78   [Cluster][EMR][XCC][A1][BKC24] SPECCPU povray ...
# 86   [EMR XCC] Prod POF enablement: S3M is not resp...
# 88   EMR PO:  Errata update - MSR for DDIO Mask won...
# 91   [EMR][PTV]  System early Cattrip On 385W EMR P...
# 126  [EMR XCC A0 PO][PC6] DMI not reporting idle an...
# 129          Lock hang on missing UPI AD credit return
# 130  [EMRPO A0][RAS] m2mem_fuse_addr_based_mem_mirr...
# 136  [EMR][A0][PO][GNR][RAS] Array bist taking too ...
# 137  [EMR A0][PM] aCode Periodic CC6 auto-demotion ...
# 171  [EMR][CXL][MCC]Post moka shows MCA_IAL_TX_RUN_...
# 183  [Cluster][MCC-XCC R1-A1]  MCA_DISPATCHER_RUN_B...
# 187  [EGS EMR][Archer City][A1][2S][RAS] Patrol scr...
# 188  [EMR XCC MMX][mmx_32gb][A1] MemMatrix MRharass...
# 198  [EMR-PO][A0][RAS]: CHA mc_status & UBOX mc_mis...
# 202  [EMR] No ptrr support for Samsung 16Gb 1B proc...
# 203  [EGS EMR][Archer City] IP prefetcher stride mu...
# 237  [EMR A1][Cafe OSPL] Acode/Ucode GPSB TO to OOB...
# 244  [NPK - ITH] Unable to send S3M FW traces from ...
# 289  [EMR PO] BMC not adjusting fan speed with CPU ...
# 291  [EMR][Rice]security issue with link_mca_ctl.ma...
# 306  [EMR][A1][CXL] reserved bits are set in H2D da...
# 310  [Cluster][XCC A1][MCA_WATCHDOG_TIMEOUT_BULK_CR...
# 313  [PO][EGS_Refresh][EMR][2S][DDR5+CXL]: Machine ...
# 348  dfx_counter_core_cc6_enter offset should be 12...
# 349  [PO][EGS_Refresh][EMR][2S][DDR5+CXL]: Uncorrec...
# 368  [Bytedance][Yichun][Nettrix] NVMe PCIe speed d...
#
#                  status_reason      submitted_date  \
# 17          complete_validated 2022-11-17 02:51:00
# 18          complete_validated 2022-11-17 03:02:00
# 23          complete_validated 2022-12-09 18:16:00
# 76   rejected_cannot_reproduce 2023-08-11 20:12:00
# 77    root_caused_pursuing_fix 2023-11-06 16:50:00
# 78    root_caused_awaiting_fix 2023-12-11 01:22:00
# 86          complete_validated 2022-10-13 21:50:00
# 88      complete_wont_validate 2022-10-21 17:54:00
# 91          complete_validated 2022-11-17 17:58:00
# 126         complete_validated 2022-10-29 00:41:00
# 129         complete_validated 2022-11-07 15:50:00
# 130         complete_validated 2022-11-07 23:36:00
# 136         complete_validated 2022-12-06 23:20:00
# 137         complete_validated 2022-12-20 23:19:00
# 171   root_caused_awaiting_fix 2023-06-16 18:06:00
# 183   root_caused_awaiting_fix 2023-09-20 20:13:00
# 187                 open_clone 2023-12-08 17:58:00
# 188   root_caused_pursuing_fix 2024-01-22 19:05:00
# 198         complete_validated 2022-10-21 14:53:00
# 202         complete_validated 2022-11-14 21:09:00
# 203         complete_validated 2022-11-16 15:12:00
# 237   root_caused_pursuing_fix 2023-12-14 22:22:00
# 244         complete_validated 2022-12-08 18:20:00
# 289         complete_validated 2022-11-10 22:19:00
# 291         complete_validated 2022-11-30 17:22:00
# 306   root_caused_pursuing_fix 2023-07-06 23:46:00
# 310   root_caused_pursuing_fix 2023-10-31 02:42:00
# 313         complete_validated 2022-11-17 17:30:00
# 348         complete_validated 2022-11-17 20:46:00
# 349         complete_validated 2022-11-30 16:30:00
# 368   root_caused_awaiting_fix 2023-11-22 02:58:00
#
#                     closed_date     owner     sighting.conclusion  \
# 17   2023-10-09 23:39:00.000000  coramire                  hw.bug
# 18   2023-10-10 21:53:00.000000  coramire                  hw.bug
# 23   2023-10-10 20:11:00.000000  coramire                  hw.bug
# 76   2024-06-19 04:14:00.000000  cadoming  no_root_cause.rejected
# 77   2024-10-31 10:22:41.334856  bcalhoon               hw.tuning
# 78   2024-10-31 10:22:41.334856  bushengw                  fw.bug
# 86   2023-10-10 20:10:00.000000  dramosol                 env.bug
# 88   2023-10-10 23:00:00.000000  dvalgano                  hw.bug
# 91   2023-10-10 21:54:00.000000  gomeseva                 env.bug
# 126  2023-10-10 21:50:00.000000  hmpicosm                  hw.bug
# 129  2023-10-09 23:39:00.000000  jmachina                  hw.bug
# 130  2023-10-10 21:51:00.000000   iherrer                  hw.bug
# 136  2023-10-09 23:28:00.000000   iherrer                  fw.bug
# 137  2023-10-10 21:49:00.000000  jlperezm                  fw.bug
# 171  2024-10-31 10:22:41.334856  jclopezg                  hw.bug
# 183  2024-10-31 10:22:41.334856    jochoa                  fw.bug
# 187  2024-10-31 10:22:41.334856     jli61                     NaN
# 188  2024-10-31 10:22:41.334856  jgodoyde                  fw.bug
# 198  2023-10-10 20:04:00.000000  jrdelsor                  fw.bug
# 202  2023-10-10 21:53:00.000000  kmwaller                 hw.arch
# 203  2023-10-10 20:13:00.000000  kputtann                  fw.bug
# 237  2024-10-31 10:22:41.334856  jtgilmer                  fw.bug
# 244  2023-10-10 21:55:00.000000  ogalvezr                  hw.bug
# 289  2023-10-10 21:52:00.000000  pungavan                 env.bug
# 291  2023-10-10 21:54:00.000000  rtander1                  hw.bug
# 306  2024-10-31 10:22:41.334856  prmarque                 env.bug
# 310  2024-10-31 10:22:41.334856   rmiller                 hw.arch
# 313  2023-10-10 22:56:00.000000   spandit                 env.bug
# 348  2023-10-10 23:00:00.000000   vchalla                  fw.bug
# 349  2023-10-10 20:12:00.000000   vthigle                 env.bug
# 368  2024-10-31 10:22:41.334856  wenweita                  fw.bug
#
#     sighting.team_found  priority_num  submitted_year  days_between
# 17          sv.enabling             2            2022           326
# 18          sv.enabling             3            2022           327
# 23          sv.enabling             2            2022           305
# 76                   sv             3            2023           312
# 77              mfg.ppv             3            2023           359
# 78          bu_platform             3            2023           325
# 86          sv.enabling             2            2022           361
# 88         sv.execution             4            2022           354
# 91          sv.enabling             3            2022           327
# 126         sv.enabling             3            2022           346
# 129                  sv             2            2022           336
# 130         sv.enabling             3            2022           336
# 136         sv.enabling             3            2022           307
# 137                  sv             2            2022           293
# 171                  sv             3            2023           502
# 183          sv.cluster             3            2023           406
# 187         bu_platform             3            2023           327
# 188                  sv             3            2024           282
# 198         sv.enabling             3            2022           354
# 202                  sv             3            2022           330
# 203         bu_platform             2            2022           328
# 237             sv.core             3            2023           321
# 244         sv.enabling             3            2022           306
# 289         sv.enabling             3            2022           333
# 291                arch             3            2022           314
# 306                  sv             3            2023           482
# 310          sv.cluster             3            2023           366
# 313         bu_platform             3            2022           327
# 348         sv.enabling             4            2022           327
# 349         bu_platform             2            2022           314
# 368    customer_support             2            2023           344

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=fd, x='priority', y='days_between')
plt.title('Days Between by Priority Level (Without Outliers)')
plt.ylabel('Days Between')
plt.xlabel('Priority')
plt.xticks(rotation=45)
plt.show()

# %%
#### QTY BY DAYS AND PRIORITY (TOTAL=353)

emr_data1[["days_between","priority"]].groupby("priority").count()
# Out:
#              days_between
# priority
# high                  129
# low                    46
# medium                163
# showstopper            15

# %%
#### QTY BY YEAR, PRIORITY (TOTAL=372)

emr_data1.groupby(["submitted_year"])["priority"].value_counts()
# Out:
# submitted_year  priority
# 2022            high            30
#                 medium          30
#                 showstopper      9
#                 low              5
# 2023            medium         137
#                 high            94
#                 low             40
#                 showstopper      4
# 2024            high            11
#                 medium           8
#                 showstopper      3
#                 low              1
# Name: count, dtype: int64

# %%
emr_data1.groupby(["submitted_year"])["status_reason"].value_counts()
# Out:
# submitted_year  status_reason
# 2022            complete_validated           46
#                 rejected_not_a_defect        14
#                 complete                      4
#                 rejected_merged               4
#                 complete_wont_validate        3
#                 rejected_filed_by_mistake     2
#                 rejected_wont_do              1
# 2023            rejected_not_a_defect        98
#                 complete_validated           68
#                 rejected_merged              29
#                 rejected_wont_do             24
#                 complete_wont_validate       17
#                 complete                     13
#                 rejected_filed_by_mistake    12
#                 rejected_cannot_reproduce     5
#                 root_caused_awaiting_fix      4
#                 root_caused_pursuing_fix      4
#                 open_clone                    1
# 2024            root_caused_pursuing_fix      6
#                 rejected_not_a_defect         5
#                 complete_validated            3
#                 root_caused_awaiting_fix      3
#                 rejected_cannot_reproduce     2
#                 rejected_wont_do              2
#                 open_clone                    1
#                 rejected_merged               1
# Name: count, dtype: int64

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

# Download stopwords and punkt if you haven't already
nltk.download('punkt')
nltk.download('stopwords')

def process_by_word_frequency(emr_data1):
    # Set of stopwords
    stop_words = set(stopwords.words('english'))
    
    # Tokenize titles and remove stopwords
    emr_data1['title_tokens'] = emr_data1['title'].apply(lambda title: [
        word for word in word_tokenize(title.lower()) if word.isalnum() and word not in stop_words
    ])
    
    # Flatten the list of all words in the 'title' column to compute frequencies
    all_words = [word for tokens in emr_data1['title_tokens'] for word in tokens]
    
    # Compute word frequency distribution
    freq_dist = FreqDist(all_words)
    
    # Assign the most frequent words in each title to a new column
    emr_data1['frequent_words'] = emr_data1['title_tokens'].apply(lambda tokens: [
        word for word in tokens if freq_dist[word] > 1  # Threshold of 1, you can adjust
    ])
    
    return emr_data1

# Apply the function to your dataset
emr_data1 = process_by_word_frequency(emr_data1)

# Show the results
emr_nlp=emr_data1[['title', 'frequent_words']].head(20)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\oscarahe\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\oscarahe\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
emr_nlp
# Out:
#                                                 title  \
# 0   [EMR] EMR system  Throttles due to External pr...
# 1   [EMR-CXL1.1][CXL][2S] BIOS needs to change Mod...
# 2   [XPV AVE] [EMR XCC A0] [UPI GEN5 SIV] Rx JTOL ...
# 3   [XPV AVE] [EMR XCC A0] [UPI GEN5 SIV] Rx JTOL ...
# 4   [EMR XCC ES2]Request sighting report for track...
# 5   [EMR XCC ES2]PIROM size display issue on EMR E...
# 6   [EMR]  Host CA Training Complex Training Failu...
# 7   [EMR] High TX DFE TAP Variability across multi...
# 8   [EMR][A1][PNP]Core Freq in powersave mode runn...
# 9   [EMR] Active Idle Mode violates MAX_RATIO from...
# 10  [EMR XCC] S3M Fuse Offload failing due to mism...
# 11  EMR-XCC: FIVR Ouput voltage saturates at highe...
# 12    PI5 pcode_sa fuse disable incorrectly programed
# 13  m2mem_m2mem_add_lut_per_meshid fuses are not p...
# 14  EMR PO: Core and LLC slice masks are different...
# 15             MDF Partify failure on  instance mdfv4
# 16  [EMR A0][PO][Coherency] IDI_Stress with TOR an...
# 17  [EMR XCC] Wrong mapping on SST-TF mailbox for ...
# 18  [EMR XCC] Wrong Turbo Bin bucket 7 impacting P...
# 19  [EMR XCC] wrong pcode_config_tdp_level_en_mask...
#
#                                        frequent_words
# 0       [emr, emr, system, due, external, 2, sockets]
# 1       [cxl, 2s, bios, needs, change, mode, all2all]
# 2   [xpv, ave, emr, xcc, a0, upi, gen5, siv, rx, j...
# 3   [xpv, ave, emr, xcc, a0, upi, gen5, siv, rx, j...
# 4   [emr, xcc, es2, request, report, pirom, size, ...
# 5   [emr, xcc, es2, pirom, size, display, issue, e...
# 6   [emr, host, ca, training, complex, training, f...
# 7   [emr, high, tx, dfe, variability, across, mult...
# 8   [emr, a1, core, freq, powersave, mode, running...
# 9            [emr, active, idle, mode, violates, msr]
# 10  [emr, xcc, s3m, fuse, offload, failing, due, m...
# 11                [fivr, voltage, higher, set, value]
# 12                  [pi5, fuse, disable, incorrectly]
# 13                                   [fuses, malgudi]
# 14                               [emr, po, core, llc]
# 15                                          [failure]
# 16                      [emr, a0, po, coherency, tor]
# 17  [emr, xcc, wrong, mapping, mailbox, cdyn, leve...
# 18      [emr, xcc, wrong, turbo, bucket, 7, po, skus]
# 19      [emr, xcc, wrong, fuse, value, enabled, skus]

# %%
emr_nlp['title'].sort_values()
# Out:
# 14    EMR PO: Core and LLC slice masks are different...
# 11    EMR-XCC: FIVR Ouput voltage saturates at highe...
# 15               MDF Partify failure on  instance mdfv4
# 12      PI5 pcode_sa fuse disable incorrectly programed
# 16    [EMR A0][PO][Coherency] IDI_Stress with TOR an...
# 5     [EMR XCC ES2]PIROM size display issue on EMR E...
# 4     [EMR XCC ES2]Request sighting report for track...
# 10    [EMR XCC] S3M Fuse Offload failing due to mism...
# 18    [EMR XCC] Wrong Turbo Bin bucket 7 impacting P...
# 17    [EMR XCC] Wrong mapping on SST-TF mailbox for ...
# 19    [EMR XCC] wrong pcode_config_tdp_level_en_mask...
# 1     [EMR-CXL1.1][CXL][2S] BIOS needs to change Mod...
# 6     [EMR]  Host CA Training Complex Training Failu...
# 9     [EMR] Active Idle Mode violates MAX_RATIO from...
# 0     [EMR] EMR system  Throttles due to External pr...
# 7     [EMR] High TX DFE TAP Variability across multi...
# 8     [EMR][A1][PNP]Core Freq in powersave mode runn...
# 3     [XPV AVE] [EMR XCC A0] [UPI GEN5 SIV] Rx JTOL ...
# 2     [XPV AVE] [EMR XCC A0] [UPI GEN5 SIV] Rx JTOL ...
# 13    m2mem_m2mem_add_lut_per_meshid fuses are not p...
# Name: title, dtype: object

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# Procesar cada texto en la columna del DataFrame
emr_data['processed'] = emr_data['sighting_central_root'].apply(lambda x: nlp(x))
print(emr_data['processed'])
# Out:
# 0     (ON, QDF, Q1CF, noticed, that, fuse, pcode_tur...
# 1     (Test, card, issue, ,, need, to, follow, up, w...
# 2     (Active, idle, addition, to, SST, in, feature,...
# 3     (Bug, on, Mcheck, with, 12way, Internleave, -,...
# 4     (Declaring, apparent, GPSB, congestion, as, ha...
# 5     (Hynix, bug, ,, more, details, on, the, hynix,...
# 6     (Known, bug, https://hsdes.intel.com/appstore/...
# 7     (BIOS, bug, ,, feature, request, here, https:/...
# 8     (Fuse, addressing, change, for, EMR, not, conv...
# 9        (Add, FUSA_CONST.PATCHLET, to, patch, release)
# 10    (See, comments, and, allied, link, sighting, h...
# 11    (aCode, patch, load, timeout, extension, fixes...
# 12    (This, issue, was, root, caused, to, AXON, lib...
# 13                                       (Pcode, patch)
# 14    (linked, server, feature, on, EMR, MisCo, agen...
# 15    (Hynix, bug, ,, more, details, on, the, hynix,...
# 16    (aCode, BugECO, 13010751184, proximate, cause,...
# 17    (kernel, bug, around, the, variable, holding, ...
# 18            (LeCroy, LA, message, decoding, error, .)
# 19    (Hynix, bug, ,, more, details, on, the, hynix,...
# 20                                      (see, comments)
# 21    (Alignment, of, pCode, structure, allocation, ...
# 22    (Astera, CXL, card, currently, not, supporting...
# 23    (PI5, instance, number, difference, between, S...
# Name: processed, dtype: object

# %%
# Extraer vectores
emr_data['vector'] = emr_data['processed'].apply(lambda doc: doc.vector)
print(emr_data['vector'])
# Out:
# 0     [-0.076082595, -0.5928076, 0.096468806, 0.3386...
# 1     [-0.30443612, -0.6960962, -0.0015609101, 0.057...
# 2     [0.12977801, -0.58392, 2.2045591e-05, 0.076181...
# 3     [-0.0120794345, -0.34809032, 0.3063973, -0.144...
# 4     [0.0034283325, -0.23453215, -0.2531319, -0.293...
# 5     [0.16463664, -0.25295958, 0.19390668, 0.193821...
# 6     [-0.24366266, -0.55158395, -0.23752287, 0.0189...
# 7     [0.07769181, -0.5744205, -0.016742637, -0.0502...
# 8     [-0.39125058, -0.4549027, 0.15959427, 0.030733...
# 9     [-0.95660096, -0.9346999, 0.4528876, 0.7715691...
# 10    [-0.26684055, 0.030095097, -0.330528, 0.357160...
# 11    [-0.2876555, -0.32623854, -0.110378996, -0.076...
# 12    [-0.15799774, -0.545754, -0.018228436, -0.0010...
# 13    [-1.0854859, -1.0469646, -0.25231403, 0.846797...
# 14    [-0.14572144, -0.23196352, -0.2161701, -0.3368...
# 15    [0.16463664, -0.25295958, 0.19390668, 0.193821...
# 16    [0.3609775, -0.4450677, -0.45428464, 0.1117053...
# 17    [0.010231137, -0.08117358, -0.19422835, 0.1614...
# 18    [-0.2849131, -0.34997132, 0.20735534, -0.03436...
# 19    [0.16463664, -0.25295958, 0.19390668, 0.193821...
# 20    [-0.77926344, 0.062383443, 0.28972772, 0.75995...
# 21    [0.09278658, -0.9230319, 0.09344247, -0.127059...
# 22    [-0.43150574, -0.22999963, 0.073283836, 0.5903...
# 23    [-0.070803896, -0.38669345, -0.092506334, -0.1...
# Name: vector, dtype: object

# %%
# Verificar la forma de los vectores
print(emr_data['vector'].apply(lambda x: x.shape))
# Out:
# 0     (96,)
# 1     (96,)
# 2     (96,)
# 3     (96,)
# 4     (96,)
# 5     (96,)
# 6     (96,)
# 7     (96,)
# 8     (96,)
# 9     (96,)
# 10    (96,)
# 11    (96,)
# 12    (96,)
# 13    (96,)
# 14    (96,)
# 15    (96,)
# 16    (96,)
# 17    (96,)
# 18    (96,)
# 19    (96,)
# 20    (96,)
# 21    (96,)
# 22    (96,)
# 23    (96,)
# Name: vector, dtype: object

# %%
priority_data = emr_data[['sighting_central_root']]
priority_data
# Out:
#                                 sighting_central_root
# 0   ON QDF Q1CF noticed that fuse pcode_turbo_rati...
# 1   Test card issue , need to follow up with that ...
# 2   Active idle addition to SST in feature linked ...
# 3   Bug on Mcheck with 12way Internleave ->  check...
# 4   Declaring apparent GPSB congestion as hardware...
# 5            Hynix bug, more details on the hynix com
# 6   Known bug https://hsdes.intel.com/appstore/art...
# 7   BIOS bug, feature request here https://hsdes.i...
# 8   Fuse addressing change for EMR not conveyed to...
# 9            Add FUSA_CONST.PATCHLET to patch release
# 10  See comments and allied link sighting https://...
# 11  aCode patch load timeout extension fixes this ...
# 12  This issue was root caused to AXON library tha...
# 13                                        Pcode patch
# 14  linked server feature on EMR MisCo agenda.  Wo...
# 15           Hynix bug, more details on the hynix com
# 16  aCode BugECO 13010751184 proximate cause of th...
# 17    kernel bug around the variable holding the size
# 18                  LeCroy LA message decoding error.
# 19           Hynix bug, more details on the hynix com
# 20                                       see comments
# 21  Alignment of pCode structure allocation to cor...
# 22  Astera CXL card currently not supporting MCTP ...
# 23  PI5 instance number difference between SPR and...

# %%
# Perform K-means clustering
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3, random_state=0)
emr_data['vector'] = kmeans.fit_predict(priority_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23904\2107359383.py in ?()
#       1 # Perform K-means clustering
#       2 from sklearn.cluster import KMeans
#       3 kmeans = KMeans(n_clusters=3, random_state=0)
# ----> 4 emr_data['vector'] = kmeans.fit_predict(priority_data)
#
# ~\AppData\Local\miniforge3\envs\jup_env\lib\site-packages\sklearn\cluster\_kmeans.py in ?(self, X, y, sample_weight)
#    1066         -------
#    1067         labels : ndarray of shape (n_samples,)
#    1068             Index of the cluster each sample belongs to.
#    1069         """
# -> 1070         return self.fit(X, sample_weight=sample_weight).labels_
#
# ~\AppData\Local\miniforge3\envs\jup_env\lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1469                 skip_parameter_validation=(
#    1470                     prefer_skip_nested_validation or global_skip_validation
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#
# ~\AppData\Local\miniforge3\envs\jup_env\lib\site-packages\sklearn\cluster\_kmeans.py in ?(self, X, y, sample_weight)
#    1460         -------
#    1461         self : object
#    1462             Fitted estimator.
#    1463         """
# -> 1464         X = self._validate_data(
#    1465             X,
#    1466             accept_sparse="csr",
#    1467             dtype=[np.float64, np.float32],
#
# ~\AppData\Local\miniforge3\envs\jup_env\lib\site-packages\sklearn\base.py in ?(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     629                 out = y
#     630             else:
#     631                 out = X, y
#     632         elif not no_val_X and no_val_y:
# --> 633             out = check_array(X, input_name="X", **check_params)
#     634         elif no_val_X and not no_val_y:
#     635             out = _check_y(y, **check_params)
#     636         else:
#
# ~\AppData\Local\miniforge3\envs\jup_env\lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1009                         )
#    1010                     array = xp.astype(array, dtype, copy=False)
#    1011                 else:
#    1012                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1013             except ComplexWarning as complex_warning:
#    1014                 raise ValueError(
#    1015                     "Complex data not supported\n{}\n".format(array)
#    1016                 ) from complex_warning
#
# ~\AppData\Local\miniforge3\envs\jup_env\lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp, device)
#     741         # Use NumPy API to support order
#     742         if copy is True:
#     743             array = numpy.array(array, order=order, dtype=dtype)
#     744         else:
# --> 745             array = numpy.asarray(array, order=order, dtype=dtype)
#     746
#     747         # At this point array is a NumPy ndarray. We convert it to an array
#     748         # container that is consistent with the input's namespace.
#
# ~\AppData\Local\miniforge3\envs\jup_env\lib\site-packages\pandas\core\generic.py in ?(self, dtype, copy)
#    2149     def __array__(
#    2150         self, dtype: npt.DTypeLike | None = None, copy: bool_t | None = None
#    2151     ) -> np.ndarray:
#    2152         values = self._values
# -> 2153         arr = np.asarray(values, dtype=dtype)
#    2154         if (
#    2155             astype_is_view(values.dtype, arr.dtype)
#    2156             and using_copy_on_write()
#
# ValueError: could not convert string to float: 'ON QDF Q1CF noticed that fuse pcode_turbo_ratio_limit_ratios_cdyn_index3_ratio7=0x1a has a wrong value'

# %%
# Count the number of sightings in each cluster
cluster_counts = emr_data['vector'].value_counts().sort_index()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 2
#       1 # Count the number of sightings in each cluster
# ----> 2 cluster_counts = emr_data['vector'].value_counts().sort_index()
#
# File ~\AppData\Local\miniforge3\envs\jup_env\lib\site-packages\pandas\core\series.py:4069, in Series.sort_index(self, axis, level, ascending, inplace, kind, na_position, sort_remaining, ignore_index, key)
#    3936 def sort_index(
#    3937     self,
#    3938     *,
#    (...)
#    3947     key: IndexKeyFunc | None = None,
#    3948 ) -> Series | None:
#    3949     """
#    3950     Sort Series by index labels.
#    3951
#    (...)
#    4066     dtype: int64
#    4067     """
# -> 4069     return super().sort_index(
#    4070         axis=axis,
#    4071         level=level,
#    4072         ascending=ascending,
#    4073         inplace=inplace,
#    4074         kind=kind,
#    4075         na_position=na_position,
#    4076         sort_remaining=sort_remaining,
#    4077         ignore_index=ignore_index,
#    4078         key=key,
#    4079     )
#
# File ~\AppData\Local\miniforge3\envs\jup_env\lib\site-packages\pandas\core\generic.py:5309, in NDFrame.sort_index(self, axis, level, ascending, inplace, kind, na_position, sort_remaining, ignore_index, key)
#    5305 ascending = validate_ascending(ascending)
#    5307 target = self._get_axis(axis)
# -> 5309 indexer = get_indexer_indexer(
#    5310     target, level, ascending, kind, na_position, sort_remaining, key
#    5311 )
#    5313 if indexer is None:
#    5314     if inplace:
#
# File ~\AppData\Local\miniforge3\envs\jup_env\lib\site-packages\pandas\core\sorting.py:113, in get_indexer_indexer(target, level, ascending, kind, na_position, sort_remaining, key)
#     108     indexer = lexsort_indexer(
#     109         codes, orders=ascending, na_position=na_position, codes_given=True
#     110     )
#     111 else:
#     112     # ascending can only be a Sequence for MultiIndex
# --> 113     indexer = nargsort(
#     114         target,
#     115         kind=kind,
#     116         ascending=cast(bool, ascending),
#     117         na_position=na_position,
#     118     )
#     119 return indexer
#
# File ~\AppData\Local\miniforge3\envs\jup_env\lib\site-packages\pandas\core\sorting.py:439, in nargsort(items, kind, ascending, na_position, key, mask)
#     437     non_nans = non_nans[::-1]
#     438     non_nan_idx = non_nan_idx[::-1]
# --> 439 indexer = non_nan_idx[non_nans.argsort(kind=kind)]
#     440 if not ascending:
#     441     indexer = indexer[::-1]
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
# Define cluster names based on the priority mapping
#inverse_priority_mapping = {v: k for k, v in vector.items()}
#cluster_names = [inverse_priority_mapping[i + 1] for i in cluster_counts.index]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[118], line 2
#       1 # Define cluster names based on the priority mapping
# ----> 2 inverse_priority_mapping = {v: k for k, v in vector.items()}
#       3 cluster_names = [inverse_priority_mapping[i + 1] for i in cluster_counts.index]
#
# NameError: name 'vector' is not defined

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Apply PCA to reduce to 2 components for visualization
pca = PCA(n_components=5)
reduced_vectors = pca.fit_transform(emr_data['vector'].tolist())

# Plot the reduced vectors
plt.figure(figsize=(10, 8))
plt.scatter(reduced_vectors[:, 0], reduced_vectors[:, 1], alpha=0.5)
plt.title('PCA of Document Vectors')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.show()

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Reduce to 2D using PCA
pca = PCA(n_components=5)
vectors_2d = pca.fit_transform(emr_data['vector'].tolist())

# Plot the 2D vectors
plt.scatter(vectors_2d[:, 0], vectors_2d[:, 1])
plt.title('PCA - 2D Representation of Word Vectors')
plt.show()

# %%
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Apply PCA to reduce to 2 components for visualization
pca = PCA(n_components=2)
reduced_vectors = pca.fit_transform(emr_data['vector'].tolist())

# Apply K-Means clustering
kmeans = KMeans(n_clusters=8, random_state=42)
emr_data['cluster'] = kmeans.fit_predict(emr_data['vector'].tolist())
centers = kmeans.cluster_centers_

# Plot clusters with centroids
plt.figure(figsize=(10, 8))
plt.scatter(reduced_vectors[:, 0], reduced_vectors[:, 1], c=emr_data['cluster'], cmap='viridis', marker='o')
plt.scatter(centers[:, 0], centers[:, 1], c='red', marker='x', s=200)
plt.title('PCA - 2D Word Vectors with K-Means Clustering and Centroids')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.show()

# %%
from sklearn.metrics import silhouette_score

silhouette_avg = silhouette_score(emr_data1['vector'].tolist(), emr_data1['cluster'])
print(f'Silhouette Score: {silhouette_avg}')
# Out:
# Silhouette Score: 0.5913869142532349

# %%
cluster_counts = emr_data['cluster'].value_counts()
print(cluster_counts)
# Out:
# cluster
# 5    11
# 1     4
# 2     3
# 0     2
# 4     1
# 6     1
# 7     1
# 3     1
# Name: count, dtype: int64

# %%
# Assuming you have cluster or label data in 'emr_data1['cluster']'
plt.scatter(vectors_2d[:, 0], vectors_2d[:, 1], c=emr_data1['cluster'], cmap='viridis')
plt.colorbar()
plt.title('PCA - 2D Representation of Word Vectors with Clustering')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\miniforge3\envs\jup_env\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cluster'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[75], line 2
#       1 # Assuming you have cluster or label data in 'emr_data1['cluster']'
# ----> 2 plt.scatter(vectors_2d[:, 0], vectors_2d[:, 1], c=emr_data1['cluster'], cmap='viridis')
#       3 plt.colorbar()
#       4 plt.title('PCA - 2D Representation of Word Vectors with Clustering')
#
# File ~\AppData\Local\miniforge3\envs\jup_env\lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\AppData\Local\miniforge3\envs\jup_env\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'cluster'

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=8, random_state=20)
emr_data['cluster'] = kmeans.fit_predict(emr_data['vector'].tolist())
centers = kmeans.cluster_centers_

# Plot clusters with centroids
plt.scatter(vectors_2d[:, 0], vectors_2d[:, 1], c=emr_data1['cluster'], cmap='viridis', marker='o')
plt.scatter(centers[:, 0], centers[:, 1], c='red', marker='x', s=200)
plt.title('PCA - 2D Word Vectors with K-Means Clustering and Centroids')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 8
#       5 centers = kmeans.cluster_centers_
#       7 # Plot clusters with centroids
# ----> 8 plt.scatter(vectors_2d[:, 0], vectors_2d[:, 1], c=emr_data1['cluster'], cmap='viridis', marker='o')
#       9 plt.scatter(centers[:, 0], centers[:, 1], c='red', marker='x', s=200)
#      10 plt.title('PCA - 2D Word Vectors with K-Means Clustering and Centroids')
#
# NameError: name 'vectors_2d' is not defined

# %%
# Calculate the mean of PCA_Component_1 and PCA_Component_2
centroid_pca1 = pca_df['PCA_Component_1'].mean()
centroid_pca2 = pca_df['PCA_Component_2'].mean()



print(f"Centroid of PCA Component 1: {centroid_pca1}")
print(f"Centroid of PCA Component 2: {centroid_pca2}")
# Out:
# Centroid of PCA Component 1: 2.3875763970433476e-18
# Centroid of PCA Component 2: 4.2379481047519416e-17

# %%
import matplotlib.pyplot as plt

# Scatter plot for PCA components
plt.figure(figsize=(8, 6))
plt.scatter(pca_df['PCA_Component_1'], pca_df['PCA_Component_2'], color='blue', label='PCA Components')

# Plot the centroid
plt.scatter(centroid_pca1, centroid_pca2, color='red', label='Centroid', s=200, edgecolor='black')

# Adding labels and title
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.title('Scatter Plot of PCA Components with Centroid')
plt.legend()

plt.show()

# %%
import pandas as pd

# Create a DataFrame for PCA results
pca_df = pd.DataFrame({
    'Index': emr_data.index,
    'Processed_Text': emr_data['sighting_central_root'],  # or use original text column
    'PCA_Component_1': vectors_2d[:, 0],
    'PCA_Component_2': vectors_2d[:, 1]
})

# Display the first few rows of the table
print(pca_df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 7
#       1 import pandas as pd
#       3 # Create a DataFrame for PCA results
#       4 pca_df = pd.DataFrame({
#       5     'Index': emr_data.index,
#       6     'Processed_Text': emr_data['sighting_central_root'],  # or use original text column
# ----> 7     'PCA_Component_1': vectors_2d[:, 0],
#       8     'PCA_Component_2': vectors_2d[:, 1]
#       9 })
#      11 # Display the first few rows of the table
#      12 print(pca_df.head())
#
# NameError: name 'vectors_2d' is not defined

# %%
# Calculate min and max for PCA Component 1
pca1_min = pca_df['PCA_Component_1'].min()
pca1_max = pca_df['PCA_Component_1'].max()

# Calculate min and max for PCA Component 2
pca2_min = pca_df['PCA_Component_2'].min()
pca2_max = pca_df['PCA_Component_2'].max()

# Display the results
print("PCA Component 1 - Min:", pca1_min, "Max:", pca1_max)
print("PCA Component 2 - Min:", pca2_min, "Max:", pca2_max)
# Out:
# PCA Component 1 - Min: -3.633930318703231 Max: 2.792239354031074
# PCA Component 2 - Min: -2.915476317970021 Max: 1.9544778791158715

# %%
pca_df[pca_df["PCA_Component_1"] ==3.5486595992506653 ]["Processed_Text"].values[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 pca_df[pca_df["PCA_Component_1"] ==3.5486595992506653 ]["Processed_Text"].values[0]
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
# Scatter plot for PCA components
plt.figure(figsize=(8, 6))
plt.scatter(pca_df['PCA_Component_1'], pca_df['PCA_Component_2'], color='blue')

# Highlight the min and max points
plt.scatter(pca1_min, pca2_min, color='red', label='Min values', s=100, edgecolor='black')
plt.scatter(pca1_max, pca2_max, color='green', label='Max values', s=100, edgecolor='black')

# Adding labels
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.title('Scatter Plot of PCA Components')
plt.legend()

plt.show()

# %%
import numpy as np

# Centroids (assuming you've already calculated them)
centroid_pca1 = pca_df['PCA_Component_1'].mean()
centroid_pca2 = pca_df['PCA_Component_2'].mean()

# Function to calculate the Euclidean distance from the centroids
def calculate_distance(row):
    return np.sqrt((row['PCA_Component_1'] - centroid_pca1)**2 + (row['PCA_Component_2'] - centroid_pca2)**2)

# Apply the function to each row in the DataFrame to calculate the distance to the centroid
pca_df['Distance_to_Centroid'] = pca_df.apply(calculate_distance, axis=1)

# Find the row with the minimum distance to the centroid (closest to the centroid)
closest_to_centroid = pca_df.loc[pca_df['Distance_to_Centroid'].idxmin()]

# Get the index of the closest title and retrieve the title from emr_data1
index_value = closest_to_centroid.name
title_closest_to_centroid = emr_data1.loc[index_value, 'title']

# Extract the PCA values for the closest point
closest_pca1 = closest_to_centroid['PCA_Component_1']
closest_pca2 = closest_to_centroid['PCA_Component_2']

print(f"The title closest to the centroid is: {title_closest_to_centroid}")
print(f"The PCA values for this title are: PCA_Component_1 = {closest_pca1}, PCA_Component_2 = {closest_pca2}")
# Out:
# The title closest to the centroid is: [ECC TF][Micron Bucket 1] RE32 fails at 5200 with UCECC
# The PCA values for this title are: PCA_Component_1 = -0.001144058497944465, PCA_Component_2 = 0.016128334253113732

# %%
from sklearn.cluster import KMeans

# Apply K-Means clustering
kmeans = KMeans(n_clusters=8, random_state=62)
emr_data['cluster'] = kmeans.fit_predict(emr_data['vector'].tolist())

# Display the cluster assignment with the title
new=print(emr_data[['id','sighting_central_root','cluster']])
new=(emr_data[['id','sighting_central_root','cluster']])
#new.to_csv("clusters.csv")
# Out:
#              id                              sighting_central_root  cluster
# 0   14018000516  ON QDF Q1CF noticed that fuse pcode_turbo_rati...        0
# 1   14018570336  Test card issue , need to follow up with that ...        6
# 2   22017895744  Active idle addition to SST in feature linked ...        3
# 3   22018161164  Bug on Mcheck with 12way Internleave ->  check...        6
# 4   15015524089  Declaring apparent GPSB congestion as hardware...        7
# 5   14018655932           Hynix bug, more details on the hynix com        1
# 6   14019877013  Known bug https://hsdes.intel.com/appstore/art...        6
# 7   14017630246  BIOS bug, feature request here https://hsdes.i...        6
# 8   14017859773  Fuse addressing change for EMR not conveyed to...        3
# 9   14017877858           Add FUSA_CONST.PATCHLET to patch release        4
# 10  14017957819  See comments and allied link sighting https://...        6
# 11  14018510311  aCode patch load timeout extension fixes this ...        6
# 12  14017688800  This issue was root caused to AXON library tha...        6
# 13  14017802202                                        Pcode patch        2
# 14  14018388083  linked server feature on EMR MisCo agenda.  Wo...        6
# 15  14018874892           Hynix bug, more details on the hynix com        1
# 16  15015216561  aCode BugECO 13010751184 proximate cause of th...        6
# 17  14018545412    kernel bug around the variable holding the size        6
# 18  14019745300                  LeCroy LA message decoding error.        7
# 19  14018583300           Hynix bug, more details on the hynix com        1
# 20  14018847685                                       see comments        5
# 21  14018008333  Alignment of pCode structure allocation to cor...        3
# 22  16019024857  Astera CXL card currently not supporting MCTP ...        6
# 23  15014729895  PI5 instance number difference between SPR and...        3

# %%
labels = kmeans.labels_

# Añadir las etiquetas al DataFrame
emr_data['cluster'] = labels

print(emr_data[['processed','sighting_central_root','cluster']].head())
# Out:
#                                            processed  \
# 0  (ON, QDF, Q1CF, noticed, that, fuse, pcode_tur...
# 1  (Test, card, issue, ,, need, to, follow, up, w...
# 2  (Active, idle, addition, to, SST, in, feature,...
# 3  (Bug, on, Mcheck, with, 12way, Internleave, -,...
# 4  (Declaring, apparent, GPSB, congestion, as, ha...
#
#                                sighting_central_root  cluster
# 0  ON QDF Q1CF noticed that fuse pcode_turbo_rati...        0
# 1  Test card issue , need to follow up with that ...        6
# 2  Active idle addition to SST in feature linked ...        3
# 3  Bug on Mcheck with 12way Internleave ->  check...        6
# 4  Declaring apparent GPSB congestion as hardware...        7

# %%
new.to_csv('clusters_nuevoDIC6.csv')

# %%
# Display titles in each cluster
for cluster_num in range(8):
    print(f"Cluster {cluster_num}:")
    cluster_titles = emr_data[emr_data['cluster'] == cluster_num]['sighting_central_root'].values
    for sighting_central_root in cluster_titles:
        print(f" - {sighting_central_root}")
    print("\n")#Creates a blank line
# Out:
# Cluster 0:
#  - ON QDF Q1CF noticed that fuse pcode_turbo_ratio_limit_ratios_cdyn_index3_ratio7=0x1a has a wrong value
#
#
# Cluster 1:
#  - Hynix bug, more details on the hynix com
#  - Hynix bug, more details on the hynix com
#  - Hynix bug, more details on the hynix com
#
#
# Cluster 2:
#  - Pcode patch
#
#
# Cluster 3:
#  - Active idle addition to SST in feature linked to SPR sighting
#  - Fuse addressing change for EMR not conveyed to pCode workaround
#  - Alignment of pCode structure allocation to core count maximum
#  - PI5 instance number difference between SPR and EMR led to hole in EMR LTM mapping
#
#
# Cluster 4:
#  - Add FUSA_CONST.PATCHLET to patch release
#
#
# Cluster 5:
#  - see comments
#
#
# Cluster 6:
#  - Test card issue , need to follow up with that team
#  - Bug on Mcheck with 12way Internleave ->  check channel wayness only for protected memory , IP bug here https://hsdes.intel.com/appstore/article/#/13010830858
#  - Known bug https://hsdes.intel.com/appstore/article/#/16020034811 will take same path as SPR
#  - BIOS bug, feature request here https://hsdes.intel.com/appstore/article/#/22015797612
#  - See comments and allied link sighting https://hsdes.intel.com/appstore/article/#/14018008333
#  - aCode patch load timeout extension fixes this issue.
#  - This issue was root caused to AXON library that bootscript framework call when collect all debug logger generated by EMR bootscript.  The current WA is disable AXON into EMR bootscript until AXON team fix the HSD  https://hsdes.intel.com/appstore/article/#/14017689443.
#
#
#
# The EMR bootscript users only need to applied "git pull" to get the bootscript WA.
#  - linked server feature on EMR MisCo agenda.  Work with BIOS team for implementation underway.
#  - aCode BugECO 13010751184 proximate cause of this issue
#  - kernel bug around the variable holding the size
#  - Astera CXL card currently not supporting MCTP flows
#
#
# Cluster 7:
#  - Declaring apparent GPSB congestion as hardware issue.
#  - LeCroy LA message decoding error.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(emr_data1['vector'].tolist(), emr_data1['days_between'], test_size=0.3, random_state=42)

# Train a logistic regression model
clf = LogisticRegression()
clf.fit(X_train, y_train)

# Evaluate the model
print("Model accuracy: ", clf.score(X_test, y_test))
# Out:
# Model accuracy:  0.0625

# %%
from sklearn.linear_model import LinearRegression

# Train a linear regression model
reg = LinearRegression()
reg.fit(X_train, y_train)

# Evaluate the model
print("Model R^2 score: ", reg.score(X_test, y_test))
# Out:
# Model R^2 score:  -0.7886431217193604

# %%
from sklearn.ensemble import RandomForestRegressor

# Train a random forest regressor
rf = RandomForestRegressor()
rf.fit(X_train, y_train)

# Evaluate the model
print("Model R^2 score: ", rf.score(X_test, y_test))
# Out:
# Model R^2 score:  -0.0420700744608864

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Calculate cosine similarity between vectors
similarity_matrix = cosine_similarity(emr_data1['vector'].tolist())

# Display similarity matrix
print(similarity_matrix)
# Out:
# [[0.9999999  0.48714408 0.6706345  ... 0.60565263 0.5236038  0.6578199 ]
#  [0.48714408 0.9999999  0.5594558  ... 0.67530334 0.51681894 0.5264227 ]
#  [0.6706345  0.5594558  0.9999998  ... 0.7378689  0.5968982  0.7253362 ]
#  ...
#  [0.60565263 0.67530334 0.7378689  ... 1.0000002  0.5153497  0.63437253]
#  [0.5236038  0.51681894 0.5968982  ... 0.5153497  0.99999994 0.6416299 ]
#  [0.6578199  0.5264227  0.7253362  ... 0.63437253 0.6416299  1.        ]]

# %%
emr_data1[emr_data1["days_between"] == 0]["title"].values[0]
# Out:
# '[EMR-CXL1.1][CXL][2S] BIOS needs to change Mode to All2All when Heteromode is chosen'

# %%
emr_data1[emr_data1["days_between"] == 0]["title"].values
# Out:
# array(['[EMR-CXL1.1][CXL][2S] BIOS needs to change Mode to All2All when Heteromode is chosen',
#        '[EMR XCC ES2]Request sighting report for tracking about the PIROM size display issue on EMR ES2 XCC/MCC (A0/R0).',
#        '[EMR] Active Idle Mode violates MAX_RATIO from MSR 0x620',
#        '[EMR_A0] PCU/Acode MCAs during OSPL and Cafe Ucode_update recipe',
#        '[Cluster][EMR][XCC][A0][BKC13]MLC latency performance drop ~11.9% in BKC13 compare to BKC11',
#        '[EMR][MCC][R1][SST-TF] virtual.pcode_runtime_fact_config_0_turbo_ratio_limit_ratios_cdyn_index4_ratio0',
#        '[EMR][MCC][R1][SST-TF] virtual.pcode_runtime_fact_config_0_turbo_ratio_limit_ratios_cdyn_index4_ratio0',
#        '[EMR A0][PO][Coherency][CXL] SUT hang on GM03WVAW2736 when executing Lock Stress + CXL',
#        '[EMR MCC PO] 3DS 4Rx4 (2Hi) 1DPC test fails JedecIt check. Violation of -1',
#        '[EMR] [RAS] Parity Errors Reported After SUT reset when Viral Alert enabled in Bios Menu (surprise warm reset after viral/ierr condition)',
#        '[EMR] OOBMSM timeout (700ms) requires BMC to retry 700ms for ALL commands',
#        '[EMR A0 VV][HSIO][2S][UPI][XCC]: Observing CPU Off while performing upi_non_ras_mixed_link_speed_mesh_special_cycles test on EMR 2DPC system',
#        'EMR DSA DPDK dmadev_autotest failed with "Data mismatch at char 0"',
#        '[EMR][TME] Booting halts when TME',
#        '[EMR-A0][TDX] Few CPU intensive workload KPIs missing targets',
#        '[EMR A0] IO_Telemetry fields for DTS_0 on Core, PI5 and UPI reporting 0',
#        '[EMR A0 VV][HSIO][2S][PCIe] MCE hit after reset with broadcom switch',
#        '[EMR A0 VV][HSIO][2S][PCIe] Zero bandwidth observed for PTG Rd/RdWr on RPB/MSB',
#        '[EGS EMR][Archer City][A1][2S][RAS] Patrol scrub error is too slow with stress-ng workload',
#        '[EMR-XCC][A0 VIS][Incoming DPM][PM] Units with Malgudi core replacement failing to boot for stuck RCSM states during IIO initialization totaling 108k DPM',
#        '[EMR][XCC] CXL link down after inject cxl.mem data or address parity error if poison disabled even DPC disable',
#        '[EGS-R][EMR][MCC] Observing hung issue  while executing SST-TF test case'],
#       dtype=object)

# %%
plt.rcParams['figure.figsize'] = [8,4]
plt.rcParams['figure.dpi'] = 80

# %%
sns.countplot(data=emr_data1, x='priority_num')
plt.title('Real or Not Real Disaster Tweet')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 sns.countplot(data=similarity_matrix, x='priority_num')
#       2 plt.title('Real or Not Real Disaster Tweet')
#
# File ~\AppData\Local\miniforge3\envs\jup_env\lib\site-packages\seaborn\categorical.py:2631, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2628 elif x is not None and y is not None:
#    2629     raise TypeError("Cannot pass values for both `x` and `y`.")
# -> 2631 p = _CategoricalAggPlotter(
#    2632     data=data,
#    2633     variables=dict(x=x, y=y, hue=hue),
#    2634     order=order,
#    2635     orient=orient,
#    2636     color=color,
#    2637     legend=legend,
#    2638 )
#    2640 if ax is None:
#    2641     ax = plt.gca()
#
# File ~\AppData\Local\miniforge3\envs\jup_env\lib\site-packages\seaborn\categorical.py:67, in _CategoricalPlotter.__init__(self, data, variables, order, orient, require_numeric, color, legend)
#      56 def __init__(
#      57     self,
#      58     data=None,
#    (...)
#      64     legend="auto",
#      65 ):
# ---> 67     super().__init__(data=data, variables=variables)
#      69     # This method takes care of some bookkeeping that is necessary because the
#      70     # original categorical plots (prior to the 2021 refactor) had some rules that
#      71     # don't fit exactly into VectorPlotter logic. It may be wise to have a second
#    (...)
#      76     # default VectorPlotter rules. If we do decide to make orient part of the
#      77     # _base variable assignment, we'll want to figure out how to express that.
#      78     if self.input_format == "wide" and orient in ["h", "y"]:
#
# File ~\AppData\Local\miniforge3\envs\jup_env\lib\site-packages\seaborn\_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File ~\AppData\Local\miniforge3\envs\jup_env\lib\site-packages\seaborn\_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File ~\AppData\Local\miniforge3\envs\jup_env\lib\site-packages\seaborn\_core\data.py:57, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
# ---> 57     data = handle_data_source(data)
#      58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#
# File ~\AppData\Local\miniforge3\envs\jup_env\lib\site-packages\seaborn\_core\data.py:278, in handle_data_source(data)
#     276 elif data is not None and not isinstance(data, Mapping):
#     277     err = f"Data source must be a DataFrame or Mapping, not {type(data)!r}."
# --> 278     raise TypeError(err)
#     280 return data
#
# TypeError: Data source must be a DataFrame or Mapping, not <class 'numpy.ndarray'>.

# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Load the dataset
data=pd.read_csv('C:/Users/oscarahe/OneDrive - Intel Corporation/Desktop/Exceles/clustertres.csv')
data

# Extract the priority column
priority_data = data[['sighting_central_root']]

# Convert priority to numerical values if necessary
#priority_mapping = {'4-low': 1, '3-medium': 2, '2-high': 3, '1-showstopper': 4}
priority_data['sighting_central_root'] = priority_data['sighting_central_root']

# Perform K-means clustering
kmeans = KMeans(n_clusters=4, random_state=0)
data['sighting_central_root'] = kmeans.fit_predict(priority_data)

# Count the number of sightings in each cluster
cluster_counts = data['cluster'].value_counts().sort_index()

# Define cluster names based on the priority mapping
inverse_priority_mapping = {v: k for k, v in priority_mapping.items()}
cluster_names = [inverse_priority_mapping[i + 1] for i in cluster_counts.index]

# Plot the clusters using a bar graph
plt.bar(cluster_counts.index, cluster_counts.values, color='blue')
plt.xlabel('Cluster')
plt.ylabel('Quantity')
plt.title('K-means Clustering of Sightings Based on Priority')
plt.xticks(cluster_counts.index, cluster_names)
plt.show()
# Out:
# C:\Users\oscarahe\AppData\Local\Temp\ipykernel_23904\3123077641.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priority_data['sighting_central_root'] = priority_data['sighting_central_root']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23904\3123077641.py in ?()
#      14 priority_data['sighting_central_root'] = priority_data['sighting_central_root']
#      15
#      16 # Perform K-means clustering
#      17 kmeans = KMeans(n_clusters=4, random_state=0)
# ---> 18 data['sighting_central_root'] = kmeans.fit_predict(priority_data)
#      19
#      20 # Count the number of sightings in each cluster
#      21 cluster_counts = data['cluster'].value_counts().sort_index()
#
# ~\AppData\Local\miniforge3\envs\jup_env\lib\site-packages\sklearn\cluster\_kmeans.py in ?(self, X, y, sample_weight)
#    1066         -------
#    1067         labels : ndarray of shape (n_samples,)
#    1068             Index of the cluster each sample belongs to.
#    1069         """
# -> 1070         return self.fit(X, sample_weight=sample_weight).labels_
#
# ~\AppData\Local\miniforge3\envs\jup_env\lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1469                 skip_parameter_validation=(
#    1470                     prefer_skip_nested_validation or global_skip_validation
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#
# ~\AppData\Local\miniforge3\envs\jup_env\lib\site-packages\sklearn\cluster\_kmeans.py in ?(self, X, y, sample_weight)
#    1460         -------
#    1461         self : object
#    1462             Fitted estimator.
#    1463         """
# -> 1464         X = self._validate_data(
#    1465             X,
#    1466             accept_sparse="csr",
#    1467             dtype=[np.float64, np.float32],
#
# ~\AppData\Local\miniforge3\envs\jup_env\lib\site-packages\sklearn\base.py in ?(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     629                 out = y
#     630             else:
#     631                 out = X, y
#     632         elif not no_val_X and no_val_y:
# --> 633             out = check_array(X, input_name="X", **check_params)
#     634         elif no_val_X and not no_val_y:
#     635             out = _check_y(y, **check_params)
#     636         else:
#
# ~\AppData\Local\miniforge3\envs\jup_env\lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1009                         )
#    1010                     array = xp.astype(array, dtype, copy=False)
#    1011                 else:
#    1012                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1013             except ComplexWarning as complex_warning:
#    1014                 raise ValueError(
#    1015                     "Complex data not supported\n{}\n".format(array)
#    1016                 ) from complex_warning
#
# ~\AppData\Local\miniforge3\envs\jup_env\lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp, device)
#     741         # Use NumPy API to support order
#     742         if copy is True:
#     743             array = numpy.array(array, order=order, dtype=dtype)
#     744         else:
# --> 745             array = numpy.asarray(array, order=order, dtype=dtype)
#     746
#     747         # At this point array is a NumPy ndarray. We convert it to an array
#     748         # container that is consistent with the input's namespace.
#
# ~\AppData\Local\miniforge3\envs\jup_env\lib\site-packages\pandas\core\generic.py in ?(self, dtype, copy)
#    2149     def __array__(
#    2150         self, dtype: npt.DTypeLike | None = None, copy: bool_t | None = None
#    2151     ) -> np.ndarray:
#    2152         values = self._values
# -> 2153         arr = np.asarray(values, dtype=dtype)
#    2154         if (
#    2155             astype_is_view(values.dtype, arr.dtype)
#    2156             and using_copy_on_write()
#
# ValueError: could not convert string to float: 'ON QDF Q1CF noticed that fuse pcode_turbo_ratio_limit_ratios_cdyn_index3_ratio7=0x1a has a wrong value'
