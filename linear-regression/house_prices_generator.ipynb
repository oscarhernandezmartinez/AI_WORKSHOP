# %%
import numpy as np
import  matplotlib.pyplot as plt
import pandas as pd

# %%
import  matplotlib.pyplot as plt

# %%
def create_house_prices(num_points = 200):
    # Generar 100 números enteros aleatorios entre 80 y 120 para el eje x
    x = np.random.uniform(80, 121, num_points)
    
    # Genera 100 puntos lineales entre 1100000 y 3000000 para el eje y
    y = np.linspace(1100000, 3000000, num_points)
    
    # Ordenar los valores de x para obtener una línea recta
    x = np.sort(x)
    y = y + np.random.normal(0,250000, num_points)
    
    # Crear la gráfica
    plt.figure(figsize=(10, 6))
    plt.scatter(x, y, marker='o', color='b')
    plt.xlabel('Area (m2)')
    plt.ylabel('Price (mxn)')
    plt.grid(True)
    plt.show()

    data = pd.DataFrame({'Area':x, 'Price':y})
    data = data.round(2)
    data.to_csv('house_prices.csv', index=False)

create_house_prices()
